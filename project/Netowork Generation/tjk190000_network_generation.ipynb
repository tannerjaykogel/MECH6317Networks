# %% [markdown]
# # Amtrak Network Generation
# #### Tanner Kogel tjk190000
# ##### Mech 6317.001: Semester Project

# %% [markdown]
# ## Import needed libraries

# %%
import networkx as nx
import networkx.algorithms.community as nx_comm
from numpy import zeros, dot, array
import pickle
import matplotlib.pyplot as plt
import json
import string
import time
import itertools

# %% [markdown]
# ## Create function to take in state name and return state acronym

# %%
def state_name_to_acronym(state_name):
    with open('state_acronyms.txt' , 'r' , encoding='UTF-8') as fin: # open file of state names \t state acronym
        for line in fin:                                             # loop over every line in the txt file
            state_info = line.split('\t')                            # split line by tabs
            if state_name == state_info[0]:                          # state names line up
                return state_info[1]                                 # give state acronym

# %% [markdown]
# ## Create function to give city of train station in form city, state acronym

# %%
def city_from_station(station):
    station = station.split('(')    # break up based on station acronym
    station = station[0].split('-') # break up based on city, state acronym - station name
    return station[0].strip()       # return in form city, state acronym

# %% [markdown]
# ## Create function to give integer from string with commas

# %%
def remove_commas(string,dataType):
    string = string.replace(",","") # remove instances of commas from string
    if dataType == 'int':           # return int
        return int(string)
    elif dataType == 'float':       # return float
        return float(string)
    else:                           # error
        print('Error: input desired dataType as \'int\' or \'float\'')

# %% [markdown]
# ## Initialize graphs to be generated

# %%
G_amtrak = nx.Graph()            # weighted network of train stations
G_induced_cities = nx.Graph()    # induced graph of cities with population above 100,000 
G_noninduced_cities = nx.Graph() # non-induced graph of cities with population above 100,000

# %% [markdown]
# ## Read in city nodes with attributes from cities_from_wiki.txt

# %%
# the cities_from_wiki.txt file has data gathered from wikipedia over the 331 cities in the United States that were recorded as having a population over 100,000 in the 2020 Census
# The data is organized into \t seperated lines holding the information in the order:
# [0]pop. rank, [1]city name, [2] state name, [3] estimate of 2021 pop. based on 202 census, [4] pop. reported by 2020 census, [6] 2020 land area, etc.

with open('cities_from_wiki.txt' , 'r' , encoding='UTF-8') as fin: # open file to read cities and attributes from
    for line in fin:                                               # loop over each line from the txt file
        city_attributes = line.split('\t')                         # split city attributes into groups
        city_name = city_attributes[1]                             # get city name from list of strings
        if city_name[len(city_name)-1].isalpha() == False:         # notation bracket is present in city name
            city_name = city_name[:-3]                             # remove reference bracket (always three characters)
        city_area = city_attributes[6].split(' ')                  # get city area in square miles
        city_area = remove_commas(city_area[0],'float')            # don't include units and remove commas
        state = state_name_to_acronym(city_attributes[2])          # get state acronym
        city_state = (city_name,state)                             # put city and state in a list
        city = ', '.join(city_state)                               # final form of city node name is city, state acronym
        pop_int = remove_commas(city_attributes[4],'int')          # get poopulation as an integer
        pop_change = city_attributes[5].replace("%","")            # remove instances of unneccesary characters from string
        pop_change = float(pop_change.replace("−","-"))            # get float from string of population change
        # add node with important attributes to both city networks
        G_induced_cities.add_node(city, state=city_attributes[2], population=pop_int, population_change=pop_change, area=city_area)
        G_noninduced_cities.add_node(city, state=city_attributes[2], population=pop_int, population_change=pop_change, area=city_area)

# %% [markdown]
# ## Read in Amtrak Network from raw_amtrak.txt

# %%
# the raw_amtrak.txt file has each train station along a given amtrak route seperated by a newline, each empty line is a break betwenn routes

with open('raw_amtrak.txt' , 'r' , encoding='UTF-8') as fin: # open file to read train stations from
    amtrak_data = fin.read()                                 # get data read in as a string
    
amtrak_routes = amtrak_data.split('\n')      # get train stations in a list
is_blank = [False]*len(amtrak_routes)        # initialize list of blank (gap betweem routes) indeces
city_is_defined = [False]*len(amtrak_routes) # initialize list of stations whose cities are defined

for idx,station in enumerate(amtrak_routes):                       # loop for every station and keep track of its index
    if len(station) == 0:                                          # line is blank == gap between routes
        is_blank[idx] = True                                       # input blank line to list
        
    else: # not a break
        for city in G_noninduced_cities.nodes(): # loop over every city
            if station.find(city) != -1:         # station exists in a defined city
                city_is_defined[idx] = True      # input defined city to list
        
        
        
#    elif G_noninduced_cities.has_node(city_from_station(station)): # station is in a city on the list
#        city_is_defined[idx] = True                                # input defined city to list

                
                
                
                
                
# input data to graphs
for idx,station in enumerate(amtrak_routes): # loop over each train station and keep track of its index

    # input data to Amtrak graph
    if idx == len(amtrak_routes)-1: # last station in list
        break                       # graph is completed
    
    s1 = station              # current station in list                 
    s2 = amtrak_routes[idx+1] # next station in list
    
    if is_blank[idx] or is_blank[idx+1]: # break between routes
        continue                         # move to next set of stations
      
    if G_amtrak.has_node(s1) and G_amtrak.has_node(s2): # both nodes already exist in the graph
        if G_amtrak.has_edge(s1,s2):                    # nodes already have an edge between them
            G_amtrak[s1][s2]['weight'] += 1             # add additional weight to edge
        else:                                           # no edge exists between these nodes
            G_amtrak.add_edge(s1,s2,weight=1)           # create edge of weight 1
    else:                                               # at least one node does not exist
        G_amtrak.add_edge(s1,s2,weight=1)               # creating an edge adds nodes not in graph automatically

    # input data to non-induced city graph
    if city_is_defined[idx]:            # city at this index is defined in the list
        
        for city in G_noninduced_cities.nodes(): # loop over every city
            if station.find(city) != -1:         # station exists in a defined city
                c1 = city                        # input defined city to be used
        
#        c1 = city_from_station(station) # define first city
 
    else:                               # first city is not defined
        continue                        # move to next city in list
        
    i = 1                                    # define steps forward that are needed
    lonely_route = False                     # define term if there are no other defined cities on the route
    while city_is_defined[idx+i] == False:   # continue to loop to next city until it is defined
        i += 1                               # add value to needed steps forward
    for test in range(i):                    # loop over each line between city 1 and city 2
        if is_blank[idx+test+1]:             # next defined city is not on the current route
            lonely_route = True              # move to next route
    if lonely_route:                         # no more defined cities on route
        continue                             # do not define any more edges
    s2 = amtrak_routes[idx+i]                # define second station
    for city in G_noninduced_cities.nodes(): # loop over every city
            if s2.find(city) != -1:          # station exists in a defined city
                c2 = city                    # input defined city to be used
   
    if c1 == c2: # self-edge
        w = 2    # weight of 2
    else:        # non-self-edge
        w = 1    # weight of 1
    
    if G_noninduced_cities.has_edge(c1,c2):          # nodes already have an edge between them
        G_noninduced_cities[c1][c2]['weight'] += w   # add additional weight to edge
    else:                                            # no edge exists between these nodes
        G_noninduced_cities.add_edge(c1,c2,weight=w) # create edge of weight 1
    
# output results
print('G_amtrak:')
print('\t',G_amtrak)
print('G_noninduced_cities:')
print('\t',G_noninduced_cities)
# Out:
# G_amtrak:
# 	 Graph with 530 nodes and 592 edges
# G_noninduced_cities:
# 	 Graph with 331 nodes and 163 edges

# %% [markdown]
# ## Map amtrak network to induced city network

# %%
for edge in G_amtrak.edges(): # loop over every edge in the amtrak network
    
   # print(G_amtrak[edge[0]][edge[1]]['weight'])
    city_is_defined = [False]*len(edge)
    
    for city in G_induced_cities.nodes(): # loop over every city
            if edge[0].find(city) != -1:  # station 1 exists in a defined city
                city_1 = city             # input defined city for use
                city_is_defined[0] = True # input defined city existence
            if edge[1].find(city) != -1:  # station 2 exists in a defined city
                city_2 = city             # input defined city for use
                city_is_defined[1] = True # input defined city existance
    
    if city_is_defined[0] == False or city_is_defined[1] == False:
        continue
                
    #city_1 = city_from_station(edge[0]) # get city, state acronym for first city
    #city_2 = city_from_station(edge[1]) # get city, state acronym for second city
    
    if city_1 == city_2:                           # self-loop
        w = 2*G_amtrak[edge[0]][edge[1]]['weight'] # weight must be two for self-loop
    else:                                          # not a self-loop
        w = G_amtrak[edge[0]][edge[1]]['weight']   # weight should be equivalent to amtrak network weight
    
    if G_induced_cities.has_node(city_1) and G_induced_cities.has_node(city_2): # induced graph has both cities
        if G_induced_cities.has_edge(city_1,city_2):                            # nodes already have an edge between them
            G_induced_cities[city_1][city_2]['weight'] += w                     # add additional weight to edge
        else:                                                                   # no edge exists between these nodes
            G_induced_cities.add_edge(city_1,city_2,weight=w)                   # create edge of appropriate weight
            
     #   G_induced_cities.add_edge(city_1,city_2,weight=G_amtrak[edge[0]][edge[1]]['weight']) # create edge of appropriate weight

# print results
print('G_induced_cities:')
print('\t',G_induced_cities)
# Out:
# G_induced_cities:
# 	 Graph with 331 nodes and 74 edges

# %%
for node in G_amtrak.nodes():
    print('%s\n\t'%(node),G_amtrak[node])
# Out:
# Boston, MA - South Station (BOS)
# 	 {'Boston, MA - Back Bay Station (BBY)': {'weight': 3}, 'Rhinecliff, NY (RHI)': {'weight': 1}}
# Boston, MA - Back Bay Station (BBY)
# 	 {'Boston, MA - South Station (BOS)': {'weight': 3}, 'Route 128, MA (RTE)': {'weight': 2}, 'Framingham, MA (FRA)': {'weight': 1}}
# Route 128, MA (RTE)
# 	 {'Boston, MA - Back Bay Station (BBY)': {'weight': 2}, 'Providence, RI - Amtrak/MBTA Station (PVD)': {'weight': 2}}
# Providence, RI - Amtrak/MBTA Station (PVD)
# 	 {'Route 128, MA (RTE)': {'weight': 2}, 'New Haven, CT - Union Station (NHV)': {'weight': 1}, 'Kingston, RI (KIN)': {'weight': 1}}
# New Haven, CT - Union Station (NHV)
# 	 {'Providence, RI - Amtrak/MBTA Station (PVD)': {'weight': 1}, 'Stamford, CT (STM)': {'weight': 1}, 'New Haven, CT - State Street Station (STS)': {'weight': 3}, 'Bridgeport, CT (BRP)': {'weight': 2}, 'Wallingford, CT (WFD)': {'weight': 1}}
# Stamford, CT (STM)
# 	 {'New Haven, CT - Union Station (NHV)': {'weight': 1}, 'New York, NY - Moynihan Train Hall (NYP)': {'weight': 2}, 'Bridgeport, CT (BRP)': {'weight': 2}, 'New Rochelle, NY (NRO)': {'weight': 1}}
# New York, NY - Moynihan Train Hall (NYP)
# 	 {'Stamford, CT (STM)': {'weight': 2}, 'Newark, NJ - Penn Station (NWK)': {'weight': 7}, 'Yonkers, NY (YNY)': {'weight': 3}, 'Croton-Harmon, NY (CRT)': {'weight': 1}, 'New Rochelle, NY (NRO)': {'weight': 1}}
# Newark, NJ - Penn Station (NWK)
# 	 {'New York, NY - Moynihan Train Hall (NYP)': {'weight': 7}, 'Metropark, NJ (MET)': {'weight': 2}, 'Trenton, NJ (TRE)': {'weight': 4}, 'Newark, NJ - Liberty International Airport (EWR)': {'weight': 3}, 'New York, NY - Penn Station (NYP)': {'weight': 2}}
# Metropark, NJ (MET)
# 	 {'Newark, NJ - Penn Station (NWK)': {'weight': 2}, 'Trenton, NJ (TRE)': {'weight': 2}, 'New Brunswick, NJ (NBK)': {'weight': 3}, 'Newark, NJ - Liberty International Airport (EWR)': {'weight': 3}}
# Trenton, NJ (TRE)
# 	 {'Metropark, NJ (MET)': {'weight': 2}, 'Philadelphia, PA - William H. Gray III 30th St. Station (PHL)': {'weight': 6}, 'Newark, NJ - Penn Station (NWK)': {'weight': 4}, 'Cornwells Heights, PA (CWH)': {'weight': 3}, 'Princeton Junction, NJ (PJC)': {'weight': 3}}
# Philadelphia, PA - William H. Gray III 30th St. Station (PHL)
# 	 {'Trenton, NJ (TRE)': {'weight': 6}, 'Wilmington, DE (WIL)': {'weight': 7}, 'Ardmore, PA (ARD)': {'weight': 2}, 'North Philadelphia, PA (PHN)': {'weight': 3}}
# Wilmington, DE (WIL)
# 	 {'Philadelphia, PA - William H. Gray III 30th St. Station (PHL)': {'weight': 7}, 'Baltimore, MD - Penn Station (BAL)': {'weight': 5}, 'Newark, DE (NRK)': {'weight': 1}, 'Aberdeen, MD (ABE)': {'weight': 1}}
# Baltimore, MD - Penn Station (BAL)
# 	 {'Wilmington, DE (WIL)': {'weight': 5}, 'Baltimore, MD - BWI Thurgood Marshall Airport (BWI)': {'weight': 4}, 'Washington, DC - Union Station (WAS)': {'weight': 3}, 'Aberdeen, MD (ABE)': {'weight': 2}}
# Baltimore, MD - BWI Thurgood Marshall Airport (BWI)
# 	 {'Baltimore, MD - Penn Station (BAL)': {'weight': 4}, 'Washington, DC - Union Station (WAS)': {'weight': 1}, 'New Carrollton, MD (NCR)': {'weight': 3}}
# Washington, DC - Union Station (WAS)
# 	 {'Baltimore, MD - BWI Thurgood Marshall Airport (BWI)': {'weight': 1}, 'Rockville, MD (RKV)': {'weight': 1}, 'Baltimore, MD - Penn Station (BAL)': {'weight': 3}, 'Alexandria, VA (ALX)': {'weight': 5}, 'New Carrollton, MD (NCR)': {'weight': 3}}
# Yonkers, NY (YNY)
# 	 {'New York, NY - Moynihan Train Hall (NYP)': {'weight': 3}, 'Croton-Harmon, NY (CRT)': {'weight': 5}, 'New York, NY - Penn Station (NYP)': {'weight': 2}}
# Croton-Harmon, NY (CRT)
# 	 {'Yonkers, NY (YNY)': {'weight': 5}, 'Poughkeepsie, NY (POU)': {'weight': 6}, 'New York, NY - Moynihan Train Hall (NYP)': {'weight': 1}}
# Poughkeepsie, NY (POU)
# 	 {'Croton-Harmon, NY (CRT)': {'weight': 6}, 'Rhinecliff, NY (RHI)': {'weight': 6}}
# Rhinecliff, NY (RHI)
# 	 {'Poughkeepsie, NY (POU)': {'weight': 6}, 'Hudson, NY (HUD)': {'weight': 5}, 'Boston, MA - South Station (BOS)': {'weight': 1}}
# Hudson, NY (HUD)
# 	 {'Rhinecliff, NY (RHI)': {'weight': 5}, 'Albany-Rensselaer, NY (ALB)': {'weight': 5}}
# Albany-Rensselaer, NY (ALB)
# 	 {'Hudson, NY (HUD)': {'weight': 5}, 'Schenectady, NY (SDY)': {'weight': 5}, 'Pittsfield, MA (PIT)': {'weight': 2}}
# Schenectady, NY (SDY)
# 	 {'Albany-Rensselaer, NY (ALB)': {'weight': 5}, 'Saratoga Springs, NY (SAR)': {'weight': 2}, 'Amsterdam, NY (AMS)': {'weight': 2}, 'Utica, NY (UCA)': {'weight': 1}}
# Saratoga Springs, NY (SAR)
# 	 {'Schenectady, NY (SDY)': {'weight': 2}, 'Fort Edward, NY (FED)': {'weight': 2}}
# Fort Edward, NY (FED)
# 	 {'Saratoga Springs, NY (SAR)': {'weight': 2}, 'Whitehall, NY (WHL)': {'weight': 1}, 'Castleton, VT (CNV)': {'weight': 1}}
# Whitehall, NY (WHL)
# 	 {'Fort Edward, NY (FED)': {'weight': 1}, 'Ticonderoga, NY (FTC)': {'weight': 1}}
# Ticonderoga, NY (FTC)
# 	 {'Whitehall, NY (WHL)': {'weight': 1}, 'Port Henry, NY (POH)': {'weight': 1}}
# Port Henry, NY (POH)
# 	 {'Ticonderoga, NY (FTC)': {'weight': 1}, 'Westport, NY (WSP)': {'weight': 1}}
# Westport, NY (WSP)
# 	 {'Port Henry, NY (POH)': {'weight': 1}, 'Port Kent, NY (PRK)': {'weight': 1}}
# Port Kent, NY (PRK)
# 	 {'Westport, NY (WSP)': {'weight': 1}, 'Plattsburgh, NY (PLB)': {'weight': 1}}
# Plattsburgh, NY (PLB)
# 	 {'Port Kent, NY (PRK)': {'weight': 1}, 'Rouses Point, NY (RSP)': {'weight': 1}}
# Rouses Point, NY (RSP)
# 	 {'Plattsburgh, NY (PLB)': {'weight': 1}, 'St-Lambert, QC (SLQ)': {'weight': 1}}
# St-Lambert, QC (SLQ)
# 	 {'Rouses Point, NY (RSP)': {'weight': 1}, 'Montreal, QC - Gare Centrale/Central Station (MTR)': {'weight': 1}}
# Montreal, QC - Gare Centrale/Central Station (MTR)
# 	 {'St-Lambert, QC (SLQ)': {'weight': 1}}
# Eugene, OR - Amtrak Station (EUG)
# 	 {'Albany, OR (ALY)': {'weight': 2}, 'Chemult, OR (CMO)': {'weight': 1}}
# Albany, OR (ALY)
# 	 {'Eugene, OR - Amtrak Station (EUG)': {'weight': 2}, 'Salem, OR - Amtrak Station (SLM)': {'weight': 2}}
# Salem, OR - Amtrak Station (SLM)
# 	 {'Albany, OR (ALY)': {'weight': 2}, 'Oregon City, OR (ORC)': {'weight': 1}, 'Portland, OR - Union Station (PDX)': {'weight': 1}}
# Oregon City, OR (ORC)
# 	 {'Salem, OR - Amtrak Station (SLM)': {'weight': 1}, 'Portland, OR - Union Station (PDX)': {'weight': 1}}
# Portland, OR - Union Station (PDX)
# 	 {'Oregon City, OR (ORC)': {'weight': 1}, 'Vancouver, WA (VAN)': {'weight': 3}, 'Salem, OR - Amtrak Station (SLM)': {'weight': 1}, 'Ephrata, WA (EPH)': {'weight': 1}}
# Vancouver, WA (VAN)
# 	 {'Portland, OR - Union Station (PDX)': {'weight': 3}, 'Kelso-Longview, WA (KEL)': {'weight': 2}, 'Bingen-White Salmon, WA (BNG)': {'weight': 1}}
# Kelso-Longview, WA (KEL)
# 	 {'Vancouver, WA (VAN)': {'weight': 2}, 'Centralia, WA (CTL)': {'weight': 2}}
# Centralia, WA (CTL)
# 	 {'Kelso-Longview, WA (KEL)': {'weight': 2}, 'Olympia-Lacey, WA (OLW)': {'weight': 2}}
# Olympia-Lacey, WA (OLW)
# 	 {'Centralia, WA (CTL)': {'weight': 2}, 'Tacoma, WA (TAC)': {'weight': 2}}
# Tacoma, WA (TAC)
# 	 {'Olympia-Lacey, WA (OLW)': {'weight': 2}, 'Tukwila, WA (TUK)': {'weight': 1}, 'Seattle, WA - King Street Station (SEA)': {'weight': 1}}
# Tukwila, WA (TUK)
# 	 {'Tacoma, WA (TAC)': {'weight': 1}, 'Seattle, WA - King Street Station (SEA)': {'weight': 1}}
# Seattle, WA - King Street Station (SEA)
# 	 {'Tukwila, WA (TUK)': {'weight': 1}, 'Edmonds, WA (EDM)': {'weight': 2}, 'Tacoma, WA (TAC)': {'weight': 1}}
# Edmonds, WA (EDM)
# 	 {'Seattle, WA - King Street Station (SEA)': {'weight': 2}, 'Everett, WA (EVR)': {'weight': 2}}
# Everett, WA (EVR)
# 	 {'Edmonds, WA (EDM)': {'weight': 2}, 'Stanwood, WA (STW)': {'weight': 1}, 'Leavenworth, WA - Icicle Station (LWA)': {'weight': 1}}
# Stanwood, WA (STW)
# 	 {'Everett, WA (EVR)': {'weight': 1}, 'Mount Vernon, WA (MVW)': {'weight': 1}}
# Mount Vernon, WA (MVW)
# 	 {'Stanwood, WA (STW)': {'weight': 1}, 'Bellingham, WA (BEL)': {'weight': 1}}
# Bellingham, WA (BEL)
# 	 {'Mount Vernon, WA (MVW)': {'weight': 1}, 'Vancouver, BC - Pacific Central Station (VAC)': {'weight': 1}}
# Vancouver, BC - Pacific Central Station (VAC)
# 	 {'Bellingham, WA (BEL)': {'weight': 1}}
# Springfield, MA (SPG)
# 	 {'Windsor Locks, CT (WNL)': {'weight': 4}, 'Pittsfield, MA (PIT)': {'weight': 1}, 'Worcester, MA - Union Station (WOR)': {'weight': 1}, 'Old Saybrook, CT (OSB)': {'weight': 1}, 'Holyoke, MA (HLK)': {'weight': 2}}
# Windsor Locks, CT (WNL)
# 	 {'Springfield, MA (SPG)': {'weight': 4}, 'Windsor, CT (WND)': {'weight': 3}, 'Hartford, CT (HFD)': {'weight': 1}}
# Windsor, CT (WND)
# 	 {'Windsor Locks, CT (WNL)': {'weight': 3}, 'Hartford, CT (HFD)': {'weight': 3}}
# Hartford, CT (HFD)
# 	 {'Windsor, CT (WND)': {'weight': 3}, 'Berlin, CT (BER)': {'weight': 4}, 'Windsor Locks, CT (WNL)': {'weight': 1}}
# Berlin, CT (BER)
# 	 {'Hartford, CT (HFD)': {'weight': 4}, 'Meriden, CT (MDN)': {'weight': 4}}
# Meriden, CT (MDN)
# 	 {'Berlin, CT (BER)': {'weight': 4}, 'Wallingford, CT (WFD)': {'weight': 4}}
# Wallingford, CT (WFD)
# 	 {'Meriden, CT (MDN)': {'weight': 4}, 'New Haven, CT - State Street Station (STS)': {'weight': 3}, 'New Haven, CT - Union Station (NHV)': {'weight': 1}}
# New Haven, CT - State Street Station (STS)
# 	 {'Wallingford, CT (WFD)': {'weight': 3}, 'New Haven, CT - Union Station (NHV)': {'weight': 3}}
# Lorton, VA - Auto Train to Orlando Area (LOR)
# 	 {'Sanford, FL - Auto Train to Washington, DC Area (SFA)': {'weight': 1}}
# Sanford, FL - Auto Train to Washington, DC Area (SFA)
# 	 {'Lorton, VA - Auto Train to Orlando Area (LOR)': {'weight': 1}}
# Pittsfield, MA (PIT)
# 	 {'Albany-Rensselaer, NY (ALB)': {'weight': 2}, 'Springfield, MA (SPG)': {'weight': 1}}
# Chicago, IL - Union Station (CHI)
# 	 {'Naperville, IL (NPV)': {'weight': 2}, 'South Bend, IN (SOB)': {'weight': 2}, 'Dyer, IN (DYE)': {'weight': 1}, 'Homewood, IL (HMW)': {'weight': 1}, 'Glenview, IL (GLN)': {'weight': 2}, 'Summit, IL (SMT)': {'weight': 2}, 'Hammond-Whiting, IN (HMI)': {'weight': 1}, 'Joliet, IL (JOL)': {'weight': 1}}
# Naperville, IL (NPV)
# 	 {'Chicago, IL - Union Station (CHI)': {'weight': 2}, 'McCook, NE (MCK)': {'weight': 1}, 'La Grange, IL (LAG)': {'weight': 1}, 'Plano, IL (PLO)': {'weight': 1}, 'Mendota, IL (MDT)': {'weight': 1}}
# McCook, NE (MCK)
# 	 {'Naperville, IL (NPV)': {'weight': 1}, 'Elko, NV (ELK)': {'weight': 1}, 'Holdrege, NE (HLD)': {'weight': 1}, 'Fort Morgan, CO (FMG)': {'weight': 1}}
# Elko, NV (ELK)
# 	 {'McCook, NE (MCK)': {'weight': 1}, 'Winnemucca, NV (WNN)': {'weight': 2}, 'Salt Lake City, UT - Amtrak Station (SLC)': {'weight': 1}}
# Winnemucca, NV (WNN)
# 	 {'Elko, NV (ELK)': {'weight': 2}, 'Princeton, IL (PCT)': {'weight': 1}, 'Reno, NV (RNO)': {'weight': 1}}
# Princeton, IL (PCT)
# 	 {'Winnemucca, NV (WNN)': {'weight': 1}, 'Galesburg, IL (GBB)': {'weight': 2}, 'Mendota, IL (MDT)': {'weight': 2}, 'Kewanee, IL (KEE)': {'weight': 1}}
# Galesburg, IL (GBB)
# 	 {'Princeton, IL (PCT)': {'weight': 2}, 'Burlington, IA (BRL)': {'weight': 1}, 'Kewanee, IL (KEE)': {'weight': 1}, 'Macomb, IL (MAC)': {'weight': 1}, 'Fort Madison, IA (FMD)': {'weight': 1}}
# Burlington, IA (BRL)
# 	 {'Galesburg, IL (GBB)': {'weight': 1}, 'Mt. Pleasant, IA (MTP)': {'weight': 1}}
# Mt. Pleasant, IA (MTP)
# 	 {'Burlington, IA (BRL)': {'weight': 1}, 'Ottumwa, IA (OTM)': {'weight': 1}}
# Ottumwa, IA (OTM)
# 	 {'Mt. Pleasant, IA (MTP)': {'weight': 1}, 'Osceola, IA (OSC)': {'weight': 1}}
# Osceola, IA (OSC)
# 	 {'Ottumwa, IA (OTM)': {'weight': 1}, 'Creston, IA (CRN)': {'weight': 1}}
# Creston, IA (CRN)
# 	 {'Osceola, IA (OSC)': {'weight': 1}, 'Omaha, NE (OMA)': {'weight': 1}}
# Omaha, NE (OMA)
# 	 {'Creston, IA (CRN)': {'weight': 1}, 'Lincoln, NE (LNK)': {'weight': 1}}
# Lincoln, NE (LNK)
# 	 {'Omaha, NE (OMA)': {'weight': 1}, 'Hastings, NE (HAS)': {'weight': 1}}
# Hastings, NE (HAS)
# 	 {'Lincoln, NE (LNK)': {'weight': 1}, 'Holdrege, NE (HLD)': {'weight': 1}}
# Holdrege, NE (HLD)
# 	 {'Hastings, NE (HAS)': {'weight': 1}, 'McCook, NE (MCK)': {'weight': 1}}
# Fort Morgan, CO (FMG)
# 	 {'McCook, NE (MCK)': {'weight': 1}, 'Denver, CO - Union Station (DEN)': {'weight': 1}}
# Denver, CO - Union Station (DEN)
# 	 {'Fort Morgan, CO (FMG)': {'weight': 1}, 'Fraser-Winter Park, CO (WIP)': {'weight': 1}}
# Fraser-Winter Park, CO (WIP)
# 	 {'Denver, CO - Union Station (DEN)': {'weight': 1}, 'Granby, CO (GRA)': {'weight': 1}}
# Granby, CO (GRA)
# 	 {'Fraser-Winter Park, CO (WIP)': {'weight': 1}, 'Glenwood Springs, CO (GSC)': {'weight': 1}}
# Glenwood Springs, CO (GSC)
# 	 {'Granby, CO (GRA)': {'weight': 1}, 'Grand Junction, CO (GJT)': {'weight': 1}}
# Grand Junction, CO (GJT)
# 	 {'Glenwood Springs, CO (GSC)': {'weight': 1}, 'Green River, UT (GRI)': {'weight': 1}}
# Green River, UT (GRI)
# 	 {'Grand Junction, CO (GJT)': {'weight': 1}, 'Helper, UT (HER)': {'weight': 1}}
# Helper, UT (HER)
# 	 {'Green River, UT (GRI)': {'weight': 1}, 'Provo, UT (PRO)': {'weight': 1}}
# Provo, UT (PRO)
# 	 {'Helper, UT (HER)': {'weight': 1}, 'Salt Lake City, UT - Amtrak Station (SLC)': {'weight': 1}}
# Salt Lake City, UT - Amtrak Station (SLC)
# 	 {'Provo, UT (PRO)': {'weight': 1}, 'Elko, NV (ELK)': {'weight': 1}}
# Reno, NV (RNO)
# 	 {'Winnemucca, NV (WNN)': {'weight': 1}, 'Truckee, CA (TRU)': {'weight': 1}}
# Truckee, CA (TRU)
# 	 {'Reno, NV (RNO)': {'weight': 1}, 'Colfax, CA (COX)': {'weight': 1}}
# Colfax, CA (COX)
# 	 {'Truckee, CA (TRU)': {'weight': 1}, 'Roseville, CA (RSV)': {'weight': 1}}
# Roseville, CA (RSV)
# 	 {'Colfax, CA (COX)': {'weight': 1}, 'Sacramento, CA - Sacramento Valley Station (SAC)': {'weight': 2}, 'Rocklin, CA (RLN)': {'weight': 1}}
# Sacramento, CA - Sacramento Valley Station (SAC)
# 	 {'Roseville, CA (RSV)': {'weight': 2}, 'Davis, CA (DAV)': {'weight': 3}, 'Chico, CA (CIC)': {'weight': 1}, 'Lodi, CA (LOD)': {'weight': 1}}
# Davis, CA (DAV)
# 	 {'Sacramento, CA - Sacramento Valley Station (SAC)': {'weight': 3}, 'Martinez, CA (MTZ)': {'weight': 2}, 'Fairfield-Vacaville, CA (FFV)': {'weight': 1}}
# Martinez, CA (MTZ)
# 	 {'Davis, CA (DAV)': {'weight': 2}, 'Emeryville, CA (EMY)': {'weight': 2}, 'Suisun-Fairfield, CA (SUI)': {'weight': 1}, 'Richmond, CA (RIC)': {'weight': 2}, 'Antioch-Pittsburg, CA (ACA)': {'weight': 1}}
# Emeryville, CA (EMY)
# 	 {'Martinez, CA (MTZ)': {'weight': 2}, 'Berkeley, CA (BKY)': {'weight': 1}, 'Oakland, CA - Jack London Square Station (OKJ)': {'weight': 3}, 'Richmond, CA (RIC)': {'weight': 1}}
# Auburn, CA (ARN)
# 	 {'Rocklin, CA (RLN)': {'weight': 1}}
# Rocklin, CA (RLN)
# 	 {'Auburn, CA (ARN)': {'weight': 1}, 'Roseville, CA (RSV)': {'weight': 1}}
# Fairfield-Vacaville, CA (FFV)
# 	 {'Davis, CA (DAV)': {'weight': 1}, 'Suisun-Fairfield, CA (SUI)': {'weight': 1}}
# Suisun-Fairfield, CA (SUI)
# 	 {'Fairfield-Vacaville, CA (FFV)': {'weight': 1}, 'Martinez, CA (MTZ)': {'weight': 1}}
# Richmond, CA (RIC)
# 	 {'Martinez, CA (MTZ)': {'weight': 2}, 'Berkeley, CA (BKY)': {'weight': 1}, 'Emeryville, CA (EMY)': {'weight': 1}}
# Berkeley, CA (BKY)
# 	 {'Richmond, CA (RIC)': {'weight': 1}, 'Emeryville, CA (EMY)': {'weight': 1}}
# Oakland, CA - Jack London Square Station (OKJ)
# 	 {'Emeryville, CA (EMY)': {'weight': 3}, 'Oakland, CA - Coliseum/Airport (OAC)': {'weight': 1}, 'San Jose, CA - Diridon Station (SJC)': {'weight': 1}, 'Stockton, CA - Robert J. Cabral Station (SKT)': {'weight': 1}}
# Oakland, CA - Coliseum/Airport (OAC)
# 	 {'Oakland, CA - Jack London Square Station (OKJ)': {'weight': 1}, 'Hayward, CA (HAY)': {'weight': 1}}
# Hayward, CA (HAY)
# 	 {'Oakland, CA - Coliseum/Airport (OAC)': {'weight': 1}, 'Fremont, CA - Amtrak/ACE Station (FMT)': {'weight': 1}}
# Fremont, CA - Amtrak/ACE Station (FMT)
# 	 {'Hayward, CA (HAY)': {'weight': 1}, 'Santa Clara, CA - Great America (GAC)': {'weight': 1}}
# Santa Clara, CA - Great America (GAC)
# 	 {'Fremont, CA - Amtrak/ACE Station (FMT)': {'weight': 1}, 'Santa Clara, CA - Transit Center (SCC)': {'weight': 1}}
# Santa Clara, CA - Transit Center (SCC)
# 	 {'Santa Clara, CA - Great America (GAC)': {'weight': 1}, 'San Jose, CA - Diridon Station (SJC)': {'weight': 1}}
# San Jose, CA - Diridon Station (SJC)
# 	 {'Santa Clara, CA - Transit Center (SCC)': {'weight': 1}, 'Oakland, CA - Jack London Square Station (OKJ)': {'weight': 1}, 'Salinas, CA - Amtrak Station (SNS)': {'weight': 1}}
# Rockville, MD (RKV)
# 	 {'Washington, DC - Union Station (WAS)': {'weight': 1}, 'Harpers Ferry, WV (HFY)': {'weight': 1}}
# Harpers Ferry, WV (HFY)
# 	 {'Rockville, MD (RKV)': {'weight': 1}, 'Martinsburg, WV (MRB)': {'weight': 1}}
# Martinsburg, WV (MRB)
# 	 {'Harpers Ferry, WV (HFY)': {'weight': 1}, 'Cumberland, MD - Amtrak Station (CUM)': {'weight': 1}}
# Cumberland, MD - Amtrak Station (CUM)
# 	 {'Martinsburg, WV (MRB)': {'weight': 1}, 'Connellsville, PA (COV)': {'weight': 1}}
# Connellsville, PA (COV)
# 	 {'Cumberland, MD - Amtrak Station (CUM)': {'weight': 1}, 'Pittsburgh, PA - Union Station (PGH)': {'weight': 1}}
# Pittsburgh, PA - Union Station (PGH)
# 	 {'Connellsville, PA (COV)': {'weight': 1}, 'Alliance, OH (ALC)': {'weight': 1}, 'Greensburg, PA - Amtrak Station (GNB)': {'weight': 1}}
# Alliance, OH (ALC)
# 	 {'Pittsburgh, PA - Union Station (PGH)': {'weight': 1}, 'Cleveland, OH (CLE)': {'weight': 1}}
# Cleveland, OH (CLE)
# 	 {'Alliance, OH (ALC)': {'weight': 1}, 'Elyria, OH (ELY)': {'weight': 2}, 'Erie, PA (ERI)': {'weight': 1}}
# Elyria, OH (ELY)
# 	 {'Cleveland, OH (CLE)': {'weight': 2}, 'Sandusky, OH (SKY)': {'weight': 2}}
# Sandusky, OH (SKY)
# 	 {'Elyria, OH (ELY)': {'weight': 2}, 'Toledo, OH (TOL)': {'weight': 2}}
# Toledo, OH (TOL)
# 	 {'Sandusky, OH (SKY)': {'weight': 2}, 'Waterloo, IN (WTI)': {'weight': 1}, 'Bryan, OH (BYN)': {'weight': 1}}
# Waterloo, IN (WTI)
# 	 {'Toledo, OH (TOL)': {'weight': 1}, 'Elkhart, IN (EKH)': {'weight': 2}, 'Bryan, OH (BYN)': {'weight': 1}}
# Elkhart, IN (EKH)
# 	 {'Waterloo, IN (WTI)': {'weight': 2}, 'South Bend, IN (SOB)': {'weight': 2}}
# South Bend, IN (SOB)
# 	 {'Elkhart, IN (EKH)': {'weight': 2}, 'Chicago, IL - Union Station (CHI)': {'weight': 2}}
# Alexandria, VA (ALX)
# 	 {'Washington, DC - Union Station (WAS)': {'weight': 5}, 'Manassas, VA (MSS)': {'weight': 2}, 'Quantico, VA (QAN)': {'weight': 1}, 'Burke Centre, VA (BCV)': {'weight': 1}, 'Fredericksburg, VA (FBG)': {'weight': 1}}
# Manassas, VA (MSS)
# 	 {'Alexandria, VA (ALX)': {'weight': 2}, 'Culpeper, VA (CLP)': {'weight': 3}, 'Burke Centre, VA (BCV)': {'weight': 1}}
# Culpeper, VA (CLP)
# 	 {'Manassas, VA (MSS)': {'weight': 3}, 'Charlottesville, VA (CVS)': {'weight': 3}}
# Charlottesville, VA (CVS)
# 	 {'Culpeper, VA (CLP)': {'weight': 3}, 'Staunton, VA (STA)': {'weight': 1}, 'Lynchburg, VA (LYH)': {'weight': 2}}
# Staunton, VA (STA)
# 	 {'Charlottesville, VA (CVS)': {'weight': 1}, 'Clifton Forge, VA (CLF)': {'weight': 1}}
# Clifton Forge, VA (CLF)
# 	 {'Staunton, VA (STA)': {'weight': 1}, 'White Sulphur Springs, WV (WSS)': {'weight': 1}}
# White Sulphur Springs, WV (WSS)
# 	 {'Clifton Forge, VA (CLF)': {'weight': 1}, 'Alderson, WV (ALD)': {'weight': 1}}
# Alderson, WV (ALD)
# 	 {'White Sulphur Springs, WV (WSS)': {'weight': 1}, 'Hinton, WV (HIN)': {'weight': 1}}
# Hinton, WV (HIN)
# 	 {'Alderson, WV (ALD)': {'weight': 1}, 'Prince, WV (PRC)': {'weight': 1}}
# Prince, WV (PRC)
# 	 {'Hinton, WV (HIN)': {'weight': 1}, 'Thurmond, WV (THN)': {'weight': 1}}
# Thurmond, WV (THN)
# 	 {'Prince, WV (PRC)': {'weight': 1}, 'Montgomery, WV (MNG)': {'weight': 1}}
# Montgomery, WV (MNG)
# 	 {'Thurmond, WV (THN)': {'weight': 1}, 'Charleston, WV (CHW)': {'weight': 1}}
# Charleston, WV (CHW)
# 	 {'Montgomery, WV (MNG)': {'weight': 1}, 'Huntington, WV (HUN)': {'weight': 1}}
# Huntington, WV (HUN)
# 	 {'Charleston, WV (CHW)': {'weight': 1}, 'Ashland, KY (AKY)': {'weight': 1}}
# Ashland, KY (AKY)
# 	 {'Huntington, WV (HUN)': {'weight': 1}, 'South Shore, KY - Portsmouth, OH (SPM)': {'weight': 1}}
# South Shore, KY - Portsmouth, OH (SPM)
# 	 {'Ashland, KY (AKY)': {'weight': 1}, 'Maysville, KY (MAY)': {'weight': 1}}
# Maysville, KY (MAY)
# 	 {'South Shore, KY - Portsmouth, OH (SPM)': {'weight': 1}, 'Cincinnati, OH - Union Terminal (CIN)': {'weight': 1}}
# Cincinnati, OH - Union Terminal (CIN)
# 	 {'Maysville, KY (MAY)': {'weight': 1}, 'Connersville, IN (COI)': {'weight': 1}}
# Connersville, IN (COI)
# 	 {'Cincinnati, OH - Union Terminal (CIN)': {'weight': 1}, 'Indianapolis, IN (IND)': {'weight': 1}}
# Indianapolis, IN (IND)
# 	 {'Connersville, IN (COI)': {'weight': 1}, 'Crawfordsville, IN (CRF)': {'weight': 1}}
# Crawfordsville, IN (CRF)
# 	 {'Indianapolis, IN (IND)': {'weight': 1}, 'Lafayette, IN - Amtrak Station (LAF)': {'weight': 1}}
# Lafayette, IN - Amtrak Station (LAF)
# 	 {'Crawfordsville, IN (CRF)': {'weight': 1}, 'Rensselaer, IN (REN)': {'weight': 1}}
# Rensselaer, IN (REN)
# 	 {'Lafayette, IN - Amtrak Station (LAF)': {'weight': 1}, 'Dyer, IN (DYE)': {'weight': 1}}
# Dyer, IN (DYE)
# 	 {'Rensselaer, IN (REN)': {'weight': 1}, 'Chicago, IL - Union Station (CHI)': {'weight': 1}}
# Quantico, VA (QAN)
# 	 {'Alexandria, VA (ALX)': {'weight': 1}, 'Fredericksburg, VA (FBG)': {'weight': 2}, 'Woodbridge, VA (WDB)': {'weight': 1}}
# Fredericksburg, VA (FBG)
# 	 {'Quantico, VA (QAN)': {'weight': 2}, 'Richmond, VA - Staples Mill Road Station (RVR)': {'weight': 2}, 'Ashland, VA (ASD)': {'weight': 1}, 'Alexandria, VA (ALX)': {'weight': 1}}
# Richmond, VA - Staples Mill Road Station (RVR)
# 	 {'Fredericksburg, VA (FBG)': {'weight': 2}, 'Petersburg, VA (PTB)': {'weight': 3}, 'Ashland, VA (ASD)': {'weight': 1}}
# Petersburg, VA (PTB)
# 	 {'Richmond, VA - Staples Mill Road Station (RVR)': {'weight': 3}, 'Rocky Mount, NC (RMT)': {'weight': 2}, 'Norfolk, VA (NFK)': {'weight': 1}}
# Rocky Mount, NC (RMT)
# 	 {'Petersburg, VA (PTB)': {'weight': 2}, 'Wilson, NC (WLN)': {'weight': 2}}
# Wilson, NC (WLN)
# 	 {'Rocky Mount, NC (RMT)': {'weight': 2}, 'Selma-Smithfield, NC (SSM)': {'weight': 2}}
# Selma-Smithfield, NC (SSM)
# 	 {'Wilson, NC (WLN)': {'weight': 2}, 'Raleigh, NC - Union Station (RGH)': {'weight': 2}}
# Raleigh, NC - Union Station (RGH)
# 	 {'Selma-Smithfield, NC (SSM)': {'weight': 2}, 'Cary, NC (CYN)': {'weight': 1}, 'Fayetteville, NC (FAY)': {'weight': 1}}
# Cary, NC (CYN)
# 	 {'Raleigh, NC - Union Station (RGH)': {'weight': 1}, 'Durham, NC (DNC)': {'weight': 1}, 'Yemassee, SC (YEM)': {'weight': 1}, 'Southern Pines, NC (SOP)': {'weight': 1}}
# Durham, NC (DNC)
# 	 {'Cary, NC (CYN)': {'weight': 1}, 'Burlington, NC (BNC)': {'weight': 1}}
# Burlington, NC (BNC)
# 	 {'Durham, NC (DNC)': {'weight': 1}, 'Greensboro, NC (GRO)': {'weight': 1}}
# Greensboro, NC (GRO)
# 	 {'Burlington, NC (BNC)': {'weight': 1}, 'High Point, NC (HPT)': {'weight': 2}, 'Danville, VA (DAN)': {'weight': 1}}
# High Point, NC (HPT)
# 	 {'Greensboro, NC (GRO)': {'weight': 2}, 'Salisbury, NC (SAL)': {'weight': 2}}
# Salisbury, NC (SAL)
# 	 {'High Point, NC (HPT)': {'weight': 2}, 'Kannapolis, NC (KAN)': {'weight': 1}, 'Charlotte, NC (CLT)': {'weight': 1}}
# Kannapolis, NC (KAN)
# 	 {'Salisbury, NC (SAL)': {'weight': 1}, 'Charlotte, NC (CLT)': {'weight': 1}}
# Charlotte, NC (CLT)
# 	 {'Kannapolis, NC (KAN)': {'weight': 1}, 'Salisbury, NC (SAL)': {'weight': 1}, 'Gastonia, NC (GAS)': {'weight': 1}}
# Homewood, IL (HMW)
# 	 {'Chicago, IL - Union Station (CHI)': {'weight': 1}, 'Kankakee, IL (KKI)': {'weight': 2}, 'Quincy, IL (QCY)': {'weight': 1}}
# Kankakee, IL (KKI)
# 	 {'Homewood, IL (HMW)': {'weight': 2}, 'Champaign-Urbana, IL (CHM)': {'weight': 1}, 'Gilman, IL (GLM)': {'weight': 1}}
# Champaign-Urbana, IL (CHM)
# 	 {'Kankakee, IL (KKI)': {'weight': 1}, 'Mattoon, IL (MAT)': {'weight': 2}, 'Rantoul, IL (RTL)': {'weight': 1}}
# Mattoon, IL (MAT)
# 	 {'Champaign-Urbana, IL (CHM)': {'weight': 2}, 'Effingham, IL (EFG)': {'weight': 2}}
# Effingham, IL (EFG)
# 	 {'Mattoon, IL (MAT)': {'weight': 2}, 'Centralia, IL (CEN)': {'weight': 2}}
# Centralia, IL (CEN)
# 	 {'Effingham, IL (EFG)': {'weight': 2}, 'Carbondale, IL (CDL)': {'weight': 1}, 'Du Quoin, IL (DQN)': {'weight': 1}}
# Carbondale, IL (CDL)
# 	 {'Centralia, IL (CEN)': {'weight': 1}, 'Fulton, KY (FTN)': {'weight': 1}, 'Du Quoin, IL (DQN)': {'weight': 1}, 'Dwight, IL (DWT)': {'weight': 1}}
# Fulton, KY (FTN)
# 	 {'Carbondale, IL (CDL)': {'weight': 1}, 'Newbern-Dyersburg, TN (NBN)': {'weight': 1}}
# Newbern-Dyersburg, TN (NBN)
# 	 {'Fulton, KY (FTN)': {'weight': 1}, 'Memphis, TN - Central Station (MEM)': {'weight': 1}}
# Memphis, TN - Central Station (MEM)
# 	 {'Newbern-Dyersburg, TN (NBN)': {'weight': 1}, 'Marks, MS (MKS)': {'weight': 1}}
# Marks, MS (MKS)
# 	 {'Memphis, TN - Central Station (MEM)': {'weight': 1}, 'Greenwood, MS (GWD)': {'weight': 1}}
# Greenwood, MS (GWD)
# 	 {'Marks, MS (MKS)': {'weight': 1}, 'Yazoo City, MS (YAZ)': {'weight': 1}}
# Yazoo City, MS (YAZ)
# 	 {'Greenwood, MS (GWD)': {'weight': 1}, 'Jackson, MS (JAN)': {'weight': 1}}
# Jackson, MS (JAN)
# 	 {'Yazoo City, MS (YAZ)': {'weight': 1}, 'Hazlehurst, MS (HAZ)': {'weight': 1}}
# Hazlehurst, MS (HAZ)
# 	 {'Jackson, MS (JAN)': {'weight': 1}, 'Brookhaven, MS (BRH)': {'weight': 1}}
# Brookhaven, MS (BRH)
# 	 {'Hazlehurst, MS (HAZ)': {'weight': 1}, 'McComb, MS (MCB)': {'weight': 1}}
# McComb, MS (MCB)
# 	 {'Brookhaven, MS (BRH)': {'weight': 1}, 'Hammond, LA (HMD)': {'weight': 1}}
# Hammond, LA (HMD)
# 	 {'McComb, MS (MCB)': {'weight': 1}, 'New Orleans, LA - Union Passenger Terminal (NOL)': {'weight': 1}}
# New Orleans, LA - Union Passenger Terminal (NOL)
# 	 {'Hammond, LA (HMD)': {'weight': 1}, 'Schriever, LA (SCH)': {'weight': 1}}
# Chemult, OR (CMO)
# 	 {'Eugene, OR - Amtrak Station (EUG)': {'weight': 1}, 'Klamath Falls, OR (KFS)': {'weight': 1}}
# Klamath Falls, OR (KFS)
# 	 {'Chemult, OR (CMO)': {'weight': 1}, 'Dunsmuir, CA (DUN)': {'weight': 1}}
# Dunsmuir, CA (DUN)
# 	 {'Klamath Falls, OR (KFS)': {'weight': 1}, 'Redding, CA - Amtrak Station (RDD)': {'weight': 1}}
# Redding, CA - Amtrak Station (RDD)
# 	 {'Dunsmuir, CA (DUN)': {'weight': 1}, 'Chico, CA (CIC)': {'weight': 1}}
# Chico, CA (CIC)
# 	 {'Redding, CA - Amtrak Station (RDD)': {'weight': 1}, 'Sacramento, CA - Sacramento Valley Station (SAC)': {'weight': 1}}
# Salinas, CA - Amtrak Station (SNS)
# 	 {'San Jose, CA - Diridon Station (SJC)': {'weight': 1}, 'Paso Robles, CA (PRB)': {'weight': 1}}
# Paso Robles, CA (PRB)
# 	 {'Salinas, CA - Amtrak Station (SNS)': {'weight': 1}, 'San Luis Obispo, CA - Amtrak Station (SLO)': {'weight': 1}}
# San Luis Obispo, CA - Amtrak Station (SLO)
# 	 {'Paso Robles, CA (PRB)': {'weight': 1}, 'Santa Barbara, CA (SBA)': {'weight': 1}, 'Grover Beach, CA (GVB)': {'weight': 1}}
# Santa Barbara, CA (SBA)
# 	 {'San Luis Obispo, CA - Amtrak Station (SLO)': {'weight': 1}, 'Oxnard, CA (OXN)': {'weight': 1}, 'Goleta, CA (GTA)': {'weight': 1}, 'Carpinteria, CA (CPN)': {'weight': 1}}
# Oxnard, CA (OXN)
# 	 {'Santa Barbara, CA (SBA)': {'weight': 1}, 'Simi Valley, CA (SIM)': {'weight': 1}, 'Ventura, CA (VEC)': {'weight': 1}, 'Camarillo, CA (CML)': {'weight': 1}}
# Simi Valley, CA (SIM)
# 	 {'Oxnard, CA (OXN)': {'weight': 1}, 'Van Nuys, CA (VNC)': {'weight': 1}, 'Moorpark, CA (MPK)': {'weight': 1}, 'Chatsworth, CA (CWT)': {'weight': 1}}
# Van Nuys, CA (VNC)
# 	 {'Simi Valley, CA (SIM)': {'weight': 1}, 'Burbank, CA (BUR)': {'weight': 2}, 'Northridge, CA (NRG)': {'weight': 1}}
# Burbank, CA (BUR)
# 	 {'Van Nuys, CA (VNC)': {'weight': 2}, 'Los Angeles, CA - Union Station (LAX)': {'weight': 1}, 'Burbank, CA - Downtown (BBK)': {'weight': 1}}
# Los Angeles, CA - Union Station (LAX)
# 	 {'Burbank, CA (BUR)': {'weight': 1}, 'Glendale, CA (GDL)': {'weight': 1}, 'Fullerton, CA (FUL)': {'weight': 2}, 'Pomona, CA (POS)': {'weight': 2}}
# Lynchburg, VA (LYH)
# 	 {'Charlottesville, VA (CVS)': {'weight': 2}, 'Danville, VA (DAN)': {'weight': 1}, 'Roanoke, VA (RNK)': {'weight': 1}}
# Danville, VA (DAN)
# 	 {'Lynchburg, VA (LYH)': {'weight': 1}, 'Greensboro, NC (GRO)': {'weight': 1}}
# Gastonia, NC (GAS)
# 	 {'Charlotte, NC (CLT)': {'weight': 1}, 'Spartanburg, SC (SPB)': {'weight': 1}}
# Spartanburg, SC (SPB)
# 	 {'Gastonia, NC (GAS)': {'weight': 1}, 'Greenville, SC (GRV)': {'weight': 1}}
# Greenville, SC (GRV)
# 	 {'Spartanburg, SC (SPB)': {'weight': 1}, 'Clemson, SC (CSN)': {'weight': 1}}
# Clemson, SC (CSN)
# 	 {'Greenville, SC (GRV)': {'weight': 1}, 'Toccoa, GA (TCA)': {'weight': 1}}
# Toccoa, GA (TCA)
# 	 {'Clemson, SC (CSN)': {'weight': 1}, 'Gainesville, GA (GNS)': {'weight': 1}}
# Gainesville, GA (GNS)
# 	 {'Toccoa, GA (TCA)': {'weight': 1}, 'Atlanta, GA (ATL)': {'weight': 1}}
# Atlanta, GA (ATL)
# 	 {'Gainesville, GA (GNS)': {'weight': 1}, 'Anniston, AL (ATN)': {'weight': 1}}
# Anniston, AL (ATN)
# 	 {'Atlanta, GA (ATL)': {'weight': 1}, 'Birmingham, AL (BHM)': {'weight': 1}}
# Birmingham, AL (BHM)
# 	 {'Anniston, AL (ATN)': {'weight': 1}, 'Tuscaloosa, AL (TCL)': {'weight': 1}}
# Tuscaloosa, AL (TCL)
# 	 {'Birmingham, AL (BHM)': {'weight': 1}, 'Meridian, MS - Union Station (MEI)': {'weight': 1}}
# Meridian, MS - Union Station (MEI)
# 	 {'Tuscaloosa, AL (TCL)': {'weight': 1}, 'Laurel, MS (LAU)': {'weight': 1}}
# Laurel, MS (LAU)
# 	 {'Meridian, MS - Union Station (MEI)': {'weight': 1}, 'Hattiesburg, MS (HBG)': {'weight': 1}}
# Hattiesburg, MS (HBG)
# 	 {'Laurel, MS (LAU)': {'weight': 1}, 'Picayune, MS (PIC)': {'weight': 1}}
# Picayune, MS (PIC)
# 	 {'Hattiesburg, MS (HBG)': {'weight': 1}}
# Brunswick, ME (BRK)
# 	 {'Freeport, ME (FRE)': {'weight': 1}}
# Freeport, ME (FRE)
# 	 {'Brunswick, ME (BRK)': {'weight': 1}, 'Portland, ME (POR)': {'weight': 1}}
# Portland, ME (POR)
# 	 {'Freeport, ME (FRE)': {'weight': 1}, 'Old Orchard Beach, ME (ORB)': {'weight': 1}}
# Old Orchard Beach, ME (ORB)
# 	 {'Portland, ME (POR)': {'weight': 1}, 'Saco, ME (SAO)': {'weight': 1}}
# Saco, ME (SAO)
# 	 {'Old Orchard Beach, ME (ORB)': {'weight': 1}, 'Wells, ME (WEM)': {'weight': 1}}
# Wells, ME (WEM)
# 	 {'Saco, ME (SAO)': {'weight': 1}, 'Dover, NH (DOV)': {'weight': 1}}
# Dover, NH (DOV)
# 	 {'Wells, ME (WEM)': {'weight': 1}, 'Durham, NH (DHM)': {'weight': 1}}
# Durham, NH (DHM)
# 	 {'Dover, NH (DOV)': {'weight': 1}, 'Exeter, NH (EXR)': {'weight': 1}}
# Exeter, NH (EXR)
# 	 {'Durham, NH (DHM)': {'weight': 1}, 'Haverhill, MA (HHL)': {'weight': 1}}
# Haverhill, MA (HHL)
# 	 {'Exeter, NH (EXR)': {'weight': 1}, 'Woburn, MA (WOB)': {'weight': 1}}
# Woburn, MA (WOB)
# 	 {'Haverhill, MA (HHL)': {'weight': 1}, 'Boston, MA - North Station (BON)': {'weight': 1}}
# Boston, MA - North Station (BON)
# 	 {'Woburn, MA (WOB)': {'weight': 1}}
# Glenview, IL (GLN)
# 	 {'Chicago, IL - Union Station (CHI)': {'weight': 2}, 'Milwaukee, WI - Downtown (MKE)': {'weight': 1}, 'Sturtevant, WI (SVT)': {'weight': 1}}
# Milwaukee, WI - Downtown (MKE)
# 	 {'Glenview, IL (GLN)': {'weight': 1}, 'Columbus, WI (CBS)': {'weight': 1}, 'Milwaukee, WI - General Mitchell Airport Trains (MKA)': {'weight': 1}}
# Columbus, WI (CBS)
# 	 {'Milwaukee, WI - Downtown (MKE)': {'weight': 1}, 'Portage, WI (POG)': {'weight': 1}}
# Portage, WI (POG)
# 	 {'Columbus, WI (CBS)': {'weight': 1}, 'Wisconsin Dells, WI (WDL)': {'weight': 1}}
# Wisconsin Dells, WI (WDL)
# 	 {'Portage, WI (POG)': {'weight': 1}, 'Tomah, WI (TOH)': {'weight': 1}}
# Tomah, WI (TOH)
# 	 {'Wisconsin Dells, WI (WDL)': {'weight': 1}, 'La Crosse, WI - Amtrak Station (LSE)': {'weight': 1}}
# La Crosse, WI - Amtrak Station (LSE)
# 	 {'Tomah, WI (TOH)': {'weight': 1}, 'Winona, MN (WIN)': {'weight': 1}}
# Winona, MN (WIN)
# 	 {'La Crosse, WI - Amtrak Station (LSE)': {'weight': 1}, 'Red Wing, MN (RDW)': {'weight': 1}}
# Red Wing, MN (RDW)
# 	 {'Winona, MN (WIN)': {'weight': 1}, 'St. Paul-Minneapolis, MN - Union Depot (MSP)': {'weight': 1}}
# St. Paul-Minneapolis, MN - Union Depot (MSP)
# 	 {'Red Wing, MN (RDW)': {'weight': 1}, 'St. Cloud, MN (SCD)': {'weight': 1}}
# St. Cloud, MN (SCD)
# 	 {'St. Paul-Minneapolis, MN - Union Depot (MSP)': {'weight': 1}, 'Staples, MN (SPL)': {'weight': 1}}
# Staples, MN (SPL)
# 	 {'St. Cloud, MN (SCD)': {'weight': 1}, 'Detroit Lakes, MN (DLK)': {'weight': 1}}
# Detroit Lakes, MN (DLK)
# 	 {'Staples, MN (SPL)': {'weight': 1}, 'Fargo, ND (FAR)': {'weight': 1}}
# Fargo, ND (FAR)
# 	 {'Detroit Lakes, MN (DLK)': {'weight': 1}, 'Grand Forks, ND (GFK)': {'weight': 1}}
# Grand Forks, ND (GFK)
# 	 {'Fargo, ND (FAR)': {'weight': 1}, 'Devils Lake, ND (DVL)': {'weight': 1}}
# Devils Lake, ND (DVL)
# 	 {'Grand Forks, ND (GFK)': {'weight': 1}, 'Rugby, ND (RUG)': {'weight': 1}}
# Rugby, ND (RUG)
# 	 {'Devils Lake, ND (DVL)': {'weight': 1}, 'Minot, ND (MOT)': {'weight': 1}}
# Minot, ND (MOT)
# 	 {'Rugby, ND (RUG)': {'weight': 1}, 'Stanley, ND (STN)': {'weight': 1}}
# Stanley, ND (STN)
# 	 {'Minot, ND (MOT)': {'weight': 1}, 'Williston, ND (WTN)': {'weight': 1}}
# Williston, ND (WTN)
# 	 {'Stanley, ND (STN)': {'weight': 1}, 'Wolf Point, MT (WPT)': {'weight': 1}}
# Wolf Point, MT (WPT)
# 	 {'Williston, ND (WTN)': {'weight': 1}, 'Glasgow, MT (GGW)': {'weight': 1}}
# Glasgow, MT (GGW)
# 	 {'Wolf Point, MT (WPT)': {'weight': 1}, 'Malta, MT (MAL)': {'weight': 1}}
# Malta, MT (MAL)
# 	 {'Glasgow, MT (GGW)': {'weight': 1}, 'Havre, MT (HAV)': {'weight': 1}}
# Havre, MT (HAV)
# 	 {'Malta, MT (MAL)': {'weight': 1}, 'Shelby, MT (SBY)': {'weight': 1}}
# Shelby, MT (SBY)
# 	 {'Havre, MT (HAV)': {'weight': 1}, 'Cut Bank, MT (CUT)': {'weight': 1}}
# Cut Bank, MT (CUT)
# 	 {'Shelby, MT (SBY)': {'weight': 1}, 'Browning, MT (BRO)': {'weight': 1}}
# Browning, MT (BRO)
# 	 {'Cut Bank, MT (CUT)': {'weight': 1}, 'East Glacier Park, MT (GPK)': {'weight': 1}}
# East Glacier Park, MT (GPK)
# 	 {'Browning, MT (BRO)': {'weight': 1}, 'Essex, MT (ESM)': {'weight': 1}}
# Essex, MT (ESM)
# 	 {'East Glacier Park, MT (GPK)': {'weight': 1}, 'West Glacier, MT (WGL)': {'weight': 1}}
# West Glacier, MT (WGL)
# 	 {'Essex, MT (ESM)': {'weight': 1}, 'Whitefish, MT (WFH)': {'weight': 1}}
# Whitefish, MT (WFH)
# 	 {'West Glacier, MT (WGL)': {'weight': 1}, 'Libby, MT (LIB)': {'weight': 1}}
# Libby, MT (LIB)
# 	 {'Whitefish, MT (WFH)': {'weight': 1}, 'Sandpoint, ID (SPT)': {'weight': 1}}
# Sandpoint, ID (SPT)
# 	 {'Libby, MT (LIB)': {'weight': 1}, 'Spokane, WA - Amtrak Station (SPK)': {'weight': 1}}
# Spokane, WA - Amtrak Station (SPK)
# 	 {'Sandpoint, ID (SPT)': {'weight': 1}, 'Pasco, WA (PSC)': {'weight': 1}}
# Pasco, WA (PSC)
# 	 {'Spokane, WA - Amtrak Station (SPK)': {'weight': 1}, 'Wishram, WA (WIH)': {'weight': 1}}
# Wishram, WA (WIH)
# 	 {'Pasco, WA (PSC)': {'weight': 1}, 'Bingen-White Salmon, WA (BNG)': {'weight': 1}}
# Bingen-White Salmon, WA (BNG)
# 	 {'Wishram, WA (WIH)': {'weight': 1}, 'Vancouver, WA (VAN)': {'weight': 1}}
# Ephrata, WA (EPH)
# 	 {'Portland, OR - Union Station (PDX)': {'weight': 1}, 'Wenatchee, WA - Amtrak Station (WEN)': {'weight': 1}}
# Wenatchee, WA - Amtrak Station (WEN)
# 	 {'Ephrata, WA (EPH)': {'weight': 1}, 'Leavenworth, WA - Icicle Station (LWA)': {'weight': 1}}
# Leavenworth, WA - Icicle Station (LWA)
# 	 {'Wenatchee, WA - Amtrak Station (WEN)': {'weight': 1}, 'Everett, WA (EVR)': {'weight': 1}}
# Niagara Falls, NY (NFL)
# 	 {'Buffalo, NY - Exchange Street Station (BFX)': {'weight': 2}, 'Niagara Falls, ON (NFS)': {'weight': 1}}
# Buffalo, NY - Exchange Street Station (BFX)
# 	 {'Niagara Falls, NY (NFL)': {'weight': 2}, 'Buffalo, NY - Depew Station (BUF)': {'weight': 2}}
# Buffalo, NY - Depew Station (BUF)
# 	 {'Buffalo, NY - Exchange Street Station (BFX)': {'weight': 2}, 'Rochester, NY - Louise M. Slaughter Station (ROC)': {'weight': 3}, 'Erie, PA (ERI)': {'weight': 1}}
# Rochester, NY - Louise M. Slaughter Station (ROC)
# 	 {'Buffalo, NY - Depew Station (BUF)': {'weight': 3}, 'Syracuse, NY - Regional Transportation Center (SYR)': {'weight': 3}}
# Syracuse, NY - Regional Transportation Center (SYR)
# 	 {'Rochester, NY - Louise M. Slaughter Station (ROC)': {'weight': 3}, 'Rome, NY (ROM)': {'weight': 2}, 'Utica, NY (UCA)': {'weight': 1}}
# Rome, NY (ROM)
# 	 {'Syracuse, NY - Regional Transportation Center (SYR)': {'weight': 2}, 'Utica, NY (UCA)': {'weight': 2}}
# Utica, NY (UCA)
# 	 {'Rome, NY (ROM)': {'weight': 2}, 'Amsterdam, NY (AMS)': {'weight': 2}, 'Syracuse, NY - Regional Transportation Center (SYR)': {'weight': 1}, 'Schenectady, NY (SDY)': {'weight': 1}}
# Amsterdam, NY (AMS)
# 	 {'Utica, NY (UCA)': {'weight': 2}, 'Schenectady, NY (SDY)': {'weight': 2}}
# New York, NY - Penn Station (NYP)
# 	 {'Yonkers, NY (YNY)': {'weight': 2}, 'Newark, NJ - Penn Station (NWK)': {'weight': 2}}
# Burlington, VT - Union Station (BTN)
# 	 {'Ferrisburgh-Vergennes, VT (VRN)': {'weight': 1}}
# Ferrisburgh-Vergennes, VT (VRN)
# 	 {'Burlington, VT - Union Station (BTN)': {'weight': 1}, 'Middlebury, VT - Amtrak Station (MBY)': {'weight': 1}}
# Middlebury, VT - Amtrak Station (MBY)
# 	 {'Ferrisburgh-Vergennes, VT (VRN)': {'weight': 1}, 'Rutland, VT - James M. Jeffords Station (RUD)': {'weight': 1}}
# Rutland, VT - James M. Jeffords Station (RUD)
# 	 {'Middlebury, VT - Amtrak Station (MBY)': {'weight': 1}, 'Castleton, VT (CNV)': {'weight': 1}}
# Castleton, VT (CNV)
# 	 {'Rutland, VT - James M. Jeffords Station (RUD)': {'weight': 1}, 'Fort Edward, NY (FED)': {'weight': 1}}
# Oklahoma City, OK (OKC)
# 	 {'Norman, OK (NOR)': {'weight': 1}}
# Norman, OK (NOR)
# 	 {'Oklahoma City, OK (OKC)': {'weight': 1}, 'Purcell, OK (PUR)': {'weight': 1}}
# Purcell, OK (PUR)
# 	 {'Norman, OK (NOR)': {'weight': 1}, 'Pauls Valley, OK (PVL)': {'weight': 1}}
# Pauls Valley, OK (PVL)
# 	 {'Purcell, OK (PUR)': {'weight': 1}, 'Ardmore, OK (ADM)': {'weight': 1}}
# Ardmore, OK (ADM)
# 	 {'Pauls Valley, OK (PVL)': {'weight': 1}, 'Gainesville, TX (GLE)': {'weight': 1}}
# Gainesville, TX (GLE)
# 	 {'Ardmore, OK (ADM)': {'weight': 1}, 'Fort Worth, TX (FTW)': {'weight': 1}}
# Fort Worth, TX (FTW)
# 	 {'Gainesville, TX (GLE)': {'weight': 1}, 'Dallas, TX - Eddie Bernice Johnson Union Station (DAL)': {'weight': 1}, 'Cleburne, TX (CBR)': {'weight': 1}}
# Milwaukee, WI - General Mitchell Airport Trains (MKA)
# 	 {'Milwaukee, WI - Downtown (MKE)': {'weight': 1}, 'Sturtevant, WI (SVT)': {'weight': 1}}
# Sturtevant, WI (SVT)
# 	 {'Milwaukee, WI - General Mitchell Airport Trains (MKA)': {'weight': 1}, 'Glenview, IL (GLN)': {'weight': 1}}
# Summit, IL (SMT)
# 	 {'Chicago, IL - Union Station (CHI)': {'weight': 2}, 'Joliet, IL (JOL)': {'weight': 2}}
# Joliet, IL (JOL)
# 	 {'Summit, IL (SMT)': {'weight': 2}, 'La Grange, IL (LAG)': {'weight': 1}, 'Dwight, IL (DWT)': {'weight': 1}, 'Chicago, IL - Union Station (CHI)': {'weight': 1}, 'Pontiac, IL (PON)': {'weight': 1}}
# La Grange, IL (LAG)
# 	 {'Joliet, IL (JOL)': {'weight': 1}, 'Naperville, IL (NPV)': {'weight': 1}}
# Plano, IL (PLO)
# 	 {'Naperville, IL (NPV)': {'weight': 1}, 'Mendota, IL (MDT)': {'weight': 1}}
# Mendota, IL (MDT)
# 	 {'Plano, IL (PLO)': {'weight': 1}, 'Princeton, IL (PCT)': {'weight': 2}, 'Naperville, IL (NPV)': {'weight': 1}}
# Kewanee, IL (KEE)
# 	 {'Princeton, IL (PCT)': {'weight': 1}, 'Galesburg, IL (GBB)': {'weight': 1}}
# Macomb, IL (MAC)
# 	 {'Galesburg, IL (GBB)': {'weight': 1}, 'Quincy, IL (QCY)': {'weight': 1}}
# Quincy, IL (QCY)
# 	 {'Macomb, IL (MAC)': {'weight': 1}, 'Homewood, IL (HMW)': {'weight': 1}}
# Gilman, IL (GLM)
# 	 {'Kankakee, IL (KKI)': {'weight': 1}, 'Rantoul, IL (RTL)': {'weight': 1}}
# Rantoul, IL (RTL)
# 	 {'Gilman, IL (GLM)': {'weight': 1}, 'Champaign-Urbana, IL (CHM)': {'weight': 1}}
# Du Quoin, IL (DQN)
# 	 {'Centralia, IL (CEN)': {'weight': 1}, 'Carbondale, IL (CDL)': {'weight': 1}}
# Dwight, IL (DWT)
# 	 {'Carbondale, IL (CDL)': {'weight': 1}, 'Pontiac, IL (PON)': {'weight': 2}, 'Joliet, IL (JOL)': {'weight': 1}}
# Pontiac, IL (PON)
# 	 {'Dwight, IL (DWT)': {'weight': 2}, 'Bloomington-Normal, IL (BNL)': {'weight': 3}, 'Joliet, IL (JOL)': {'weight': 1}}
# Bloomington-Normal, IL (BNL)
# 	 {'Pontiac, IL (PON)': {'weight': 3}, 'Lincoln, IL (LCN)': {'weight': 3}}
# Lincoln, IL (LCN)
# 	 {'Bloomington-Normal, IL (BNL)': {'weight': 3}, 'Springfield, IL (SPI)': {'weight': 3}}
# Springfield, IL (SPI)
# 	 {'Lincoln, IL (LCN)': {'weight': 3}, 'Carlinville, IL (CRV)': {'weight': 3}}
# Carlinville, IL (CRV)
# 	 {'Springfield, IL (SPI)': {'weight': 3}, 'Alton, IL (ALN)': {'weight': 3}}
# Alton, IL (ALN)
# 	 {'Carlinville, IL (CRV)': {'weight': 3}, 'St. Louis, MO - Gateway Station (STL)': {'weight': 2}}
# Harrisburg, PA (HAR)
# 	 {'Middletown, PA (MID)': {'weight': 1}, 'Elizabethtown, PA (ELT)': {'weight': 1}, 'Lewistown, PA - Amtrak Station (LEW)': {'weight': 1}}
# Middletown, PA (MID)
# 	 {'Harrisburg, PA (HAR)': {'weight': 1}, 'Elizabethtown, PA (ELT)': {'weight': 1}}
# Elizabethtown, PA (ELT)
# 	 {'Middletown, PA (MID)': {'weight': 1}, 'Mount Joy, PA (MJY)': {'weight': 1}, 'Lancaster, PA (LNC)': {'weight': 1}, 'Harrisburg, PA (HAR)': {'weight': 1}}
# Mount Joy, PA (MJY)
# 	 {'Elizabethtown, PA (ELT)': {'weight': 1}, 'Lancaster, PA (LNC)': {'weight': 1}}
# Lancaster, PA (LNC)
# 	 {'Mount Joy, PA (MJY)': {'weight': 1}, 'Parkesburg, PA (PAR)': {'weight': 1}, 'Exton, PA (EXT)': {'weight': 1}, 'Elizabethtown, PA (ELT)': {'weight': 1}}
# Parkesburg, PA (PAR)
# 	 {'Lancaster, PA (LNC)': {'weight': 1}, 'Coatesville, PA (COT)': {'weight': 1}}
# Coatesville, PA (COT)
# 	 {'Parkesburg, PA (PAR)': {'weight': 1}, 'Downingtown, PA (DOW)': {'weight': 1}}
# Downingtown, PA (DOW)
# 	 {'Coatesville, PA (COT)': {'weight': 1}, 'Exton, PA (EXT)': {'weight': 1}}
# Exton, PA (EXT)
# 	 {'Downingtown, PA (DOW)': {'weight': 1}, 'Paoli, PA (PAO)': {'weight': 2}, 'Lancaster, PA (LNC)': {'weight': 1}}
# Paoli, PA (PAO)
# 	 {'Exton, PA (EXT)': {'weight': 2}, 'Ardmore, PA (ARD)': {'weight': 2}}
# Ardmore, PA (ARD)
# 	 {'Paoli, PA (PAO)': {'weight': 2}, 'Philadelphia, PA - William H. Gray III 30th St. Station (PHL)': {'weight': 2}}
# North Philadelphia, PA (PHN)
# 	 {'Philadelphia, PA - William H. Gray III 30th St. Station (PHL)': {'weight': 3}, 'Cornwells Heights, PA (CWH)': {'weight': 3}}
# Cornwells Heights, PA (CWH)
# 	 {'North Philadelphia, PA (PHN)': {'weight': 3}, 'Trenton, NJ (TRE)': {'weight': 3}}
# Princeton Junction, NJ (PJC)
# 	 {'Trenton, NJ (TRE)': {'weight': 3}, 'New Brunswick, NJ (NBK)': {'weight': 3}}
# New Brunswick, NJ (NBK)
# 	 {'Princeton Junction, NJ (PJC)': {'weight': 3}, 'Metropark, NJ (MET)': {'weight': 3}}
# Newark, NJ - Liberty International Airport (EWR)
# 	 {'Metropark, NJ (MET)': {'weight': 3}, 'Newark, NJ - Penn Station (NWK)': {'weight': 3}}
# Bryan, OH (BYN)
# 	 {'Waterloo, IN (WTI)': {'weight': 1}, 'Toledo, OH (TOL)': {'weight': 1}}
# Erie, PA (ERI)
# 	 {'Cleveland, OH (CLE)': {'weight': 1}, 'Buffalo, NY - Depew Station (BUF)': {'weight': 1}}
# Worcester, MA - Union Station (WOR)
# 	 {'Springfield, MA (SPG)': {'weight': 1}, 'Framingham, MA (FRA)': {'weight': 1}}
# Framingham, MA (FRA)
# 	 {'Worcester, MA - Union Station (WOR)': {'weight': 1}, 'Boston, MA - Back Bay Station (BBY)': {'weight': 1}}
# St. Louis, MO - Gateway Station (STL)
# 	 {'Alton, IL (ALN)': {'weight': 2}, 'Kirkwood, MO (KWD)': {'weight': 2}, 'Arcadia, MO (ACD)': {'weight': 1}}
# Kirkwood, MO (KWD)
# 	 {'St. Louis, MO - Gateway Station (STL)': {'weight': 2}, 'Washington, MO (WAH)': {'weight': 2}}
# Washington, MO (WAH)
# 	 {'Kirkwood, MO (KWD)': {'weight': 2}, 'Hermann, MO (HEM)': {'weight': 2}}
# Hermann, MO (HEM)
# 	 {'Washington, MO (WAH)': {'weight': 2}, 'Jefferson City, MO (JEF)': {'weight': 2}}
# Jefferson City, MO (JEF)
# 	 {'Hermann, MO (HEM)': {'weight': 2}, 'Sedalia, MO (SED)': {'weight': 2}}
# Sedalia, MO (SED)
# 	 {'Jefferson City, MO (JEF)': {'weight': 2}, 'Warrensburg, MO (WAR)': {'weight': 2}}
# Warrensburg, MO (WAR)
# 	 {'Sedalia, MO (SED)': {'weight': 2}, "Lee's Summit, MO (LEE)": {'weight': 2}}
# Lee's Summit, MO (LEE)
# 	 {'Warrensburg, MO (WAR)': {'weight': 2}, 'Independence, MO (IDP)': {'weight': 2}}
# Independence, MO (IDP)
# 	 {"Lee's Summit, MO (LEE)": {'weight': 2}, 'Kansas City, MO - Union Station (KCY)': {'weight': 2}}
# Kansas City, MO - Union Station (KCY)
# 	 {'Independence, MO (IDP)': {'weight': 2}, 'La Plata, MO (LAP)': {'weight': 1}, 'Lawrence, KS (LRC)': {'weight': 1}}
# Niagara Falls, ON (NFS)
# 	 {'Niagara Falls, NY (NFL)': {'weight': 1}, 'St. Catharines, ON (SCA)': {'weight': 1}}
# St. Catharines, ON (SCA)
# 	 {'Niagara Falls, ON (NFS)': {'weight': 1}, 'Grimsby, ON (GMS)': {'weight': 1}}
# Grimsby, ON (GMS)
# 	 {'St. Catharines, ON (SCA)': {'weight': 1}, 'Aldershot, ON (AST)': {'weight': 1}}
# Aldershot, ON (AST)
# 	 {'Grimsby, ON (GMS)': {'weight': 1}, 'Oakville, ON (OKL)': {'weight': 1}}
# Oakville, ON (OKL)
# 	 {'Aldershot, ON (AST)': {'weight': 1}, 'Toronto, ON - Union Station (TWO)': {'weight': 1}}
# Toronto, ON - Union Station (TWO)
# 	 {'Oakville, ON (OKL)': {'weight': 1}}
# Hammond-Whiting, IN (HMI)
# 	 {'Chicago, IL - Union Station (CHI)': {'weight': 1}, 'Michigan City, IN (MCI)': {'weight': 1}}
# Michigan City, IN (MCI)
# 	 {'Hammond-Whiting, IN (HMI)': {'weight': 1}, 'New Buffalo, MI (NBU)': {'weight': 1}}
# New Buffalo, MI (NBU)
# 	 {'Michigan City, IN (MCI)': {'weight': 1}, 'Niles, MI (NLS)': {'weight': 1}}
# Niles, MI (NLS)
# 	 {'New Buffalo, MI (NBU)': {'weight': 1}, 'Dowagiac, MI (DOA)': {'weight': 1}}
# Dowagiac, MI (DOA)
# 	 {'Niles, MI (NLS)': {'weight': 1}, 'Kalamazoo, MI (KAL)': {'weight': 1}}
# Kalamazoo, MI (KAL)
# 	 {'Dowagiac, MI (DOA)': {'weight': 1}, 'Battle Creek, MI (BTL)': {'weight': 1}}
# Battle Creek, MI (BTL)
# 	 {'Kalamazoo, MI (KAL)': {'weight': 1}, 'East Lansing, MI (LNS)': {'weight': 1}}
# East Lansing, MI (LNS)
# 	 {'Battle Creek, MI (BTL)': {'weight': 1}, 'Durand, MI (DRD)': {'weight': 1}}
# Durand, MI (DRD)
# 	 {'East Lansing, MI (LNS)': {'weight': 1}, 'Flint, MI (FLN)': {'weight': 1}}
# Flint, MI (FLN)
# 	 {'Durand, MI (DRD)': {'weight': 1}, 'Lapeer, MI (LPE)': {'weight': 1}}
# Lapeer, MI (LPE)
# 	 {'Flint, MI (FLN)': {'weight': 1}, 'Port Huron, MI (PTH)': {'weight': 1}}
# Port Huron, MI (PTH)
# 	 {'Lapeer, MI (LPE)': {'weight': 1}, 'St. Joseph-Benton Harbor, MI (SJM)': {'weight': 1}}
# St. Joseph-Benton Harbor, MI (SJM)
# 	 {'Port Huron, MI (PTH)': {'weight': 1}, 'Bangor, MI (BAM)': {'weight': 1}}
# Bangor, MI (BAM)
# 	 {'St. Joseph-Benton Harbor, MI (SJM)': {'weight': 1}, 'Holland, MI (HOM)': {'weight': 1}}
# Holland, MI (HOM)
# 	 {'Bangor, MI (BAM)': {'weight': 1}, 'Grand Rapids, MI (GRR)': {'weight': 1}}
# Grand Rapids, MI (GRR)
# 	 {'Holland, MI (HOM)': {'weight': 1}, 'Albion, MI (ALI)': {'weight': 1}}
# Albion, MI (ALI)
# 	 {'Grand Rapids, MI (GRR)': {'weight': 1}, 'Jackson, MI (JXN)': {'weight': 1}}
# Jackson, MI (JXN)
# 	 {'Albion, MI (ALI)': {'weight': 1}, 'Ann Arbor, MI (ARB)': {'weight': 1}}
# Ann Arbor, MI (ARB)
# 	 {'Jackson, MI (JXN)': {'weight': 1}, 'Dearborn, MI (DER)': {'weight': 1}}
# Dearborn, MI (DER)
# 	 {'Ann Arbor, MI (ARB)': {'weight': 1}, 'Detroit, MI (DET)': {'weight': 1}}
# Detroit, MI (DET)
# 	 {'Dearborn, MI (DER)': {'weight': 1}, 'Royal Oak, MI (ROY)': {'weight': 1}}
# Royal Oak, MI (ROY)
# 	 {'Detroit, MI (DET)': {'weight': 1}, 'Troy, MI (TRM)': {'weight': 1}}
# Troy, MI (TRM)
# 	 {'Royal Oak, MI (ROY)': {'weight': 1}, 'Pontiac, MI (PNT)': {'weight': 1}}
# Pontiac, MI (PNT)
# 	 {'Troy, MI (TRM)': {'weight': 1}}
# Kingston, RI (KIN)
# 	 {'Providence, RI - Amtrak/MBTA Station (PVD)': {'weight': 1}, 'Westerly, RI (WLY)': {'weight': 1}}
# Westerly, RI (WLY)
# 	 {'Kingston, RI (KIN)': {'weight': 1}, 'Mystic, CT (MYS)': {'weight': 1}}
# Mystic, CT (MYS)
# 	 {'Westerly, RI (WLY)': {'weight': 1}, 'New London, CT - Union Station (NLC)': {'weight': 1}}
# New London, CT - Union Station (NLC)
# 	 {'Mystic, CT (MYS)': {'weight': 1}, 'Old Saybrook, CT (OSB)': {'weight': 1}}
# Old Saybrook, CT (OSB)
# 	 {'New London, CT - Union Station (NLC)': {'weight': 1}, 'Springfield, MA (SPG)': {'weight': 1}}
# Bridgeport, CT (BRP)
# 	 {'New Haven, CT - Union Station (NHV)': {'weight': 2}, 'Stamford, CT (STM)': {'weight': 2}}
# New Rochelle, NY (NRO)
# 	 {'Stamford, CT (STM)': {'weight': 1}, 'New York, NY - Moynihan Train Hall (NYP)': {'weight': 1}}
# Newark, DE (NRK)
# 	 {'Wilmington, DE (WIL)': {'weight': 1}, 'Aberdeen, MD (ABE)': {'weight': 1}}
# Aberdeen, MD (ABE)
# 	 {'Newark, DE (NRK)': {'weight': 1}, 'Baltimore, MD - Penn Station (BAL)': {'weight': 2}, 'Wilmington, DE (WIL)': {'weight': 1}}
# New Carrollton, MD (NCR)
# 	 {'Baltimore, MD - BWI Thurgood Marshall Airport (BWI)': {'weight': 3}, 'Washington, DC - Union Station (WAS)': {'weight': 3}}
# Burke Centre, VA (BCV)
# 	 {'Alexandria, VA (ALX)': {'weight': 1}, 'Manassas, VA (MSS)': {'weight': 1}}
# Roanoke, VA (RNK)
# 	 {'Lynchburg, VA (LYH)': {'weight': 1}, 'Woodbridge, VA (WDB)': {'weight': 1}}
# Woodbridge, VA (WDB)
# 	 {'Roanoke, VA (RNK)': {'weight': 1}, 'Quantico, VA (QAN)': {'weight': 1}}
# Ashland, VA (ASD)
# 	 {'Fredericksburg, VA (FBG)': {'weight': 1}, 'Richmond, VA - Staples Mill Road Station (RVR)': {'weight': 1}}
# Norfolk, VA (NFK)
# 	 {'Petersburg, VA (PTB)': {'weight': 1}, 'Richmond, VA - Main Street Station (RVM)': {'weight': 1}}
# Richmond, VA - Main Street Station (RVM)
# 	 {'Norfolk, VA (NFK)': {'weight': 1}, 'Williamsburg, VA (WBG)': {'weight': 1}}
# Williamsburg, VA (WBG)
# 	 {'Richmond, VA - Main Street Station (RVM)': {'weight': 1}, 'Newport News, VA (NPN)': {'weight': 1}}
# Newport News, VA (NPN)
# 	 {'Williamsburg, VA (WBG)': {'weight': 1}}
# Grover Beach, CA (GVB)
# 	 {'San Luis Obispo, CA - Amtrak Station (SLO)': {'weight': 1}, 'Guadalupe, CA (GUA)': {'weight': 1}}
# Guadalupe, CA (GUA)
# 	 {'Grover Beach, CA (GVB)': {'weight': 1}, 'Lompoc-Surf, CA -Amtrak Station (LPS)': {'weight': 1}}
# Lompoc-Surf, CA -Amtrak Station (LPS)
# 	 {'Guadalupe, CA (GUA)': {'weight': 1}, 'Goleta, CA (GTA)': {'weight': 1}}
# Goleta, CA (GTA)
# 	 {'Lompoc-Surf, CA -Amtrak Station (LPS)': {'weight': 1}, 'Santa Barbara, CA (SBA)': {'weight': 1}}
# Carpinteria, CA (CPN)
# 	 {'Santa Barbara, CA (SBA)': {'weight': 1}, 'Ventura, CA (VEC)': {'weight': 1}}
# Ventura, CA (VEC)
# 	 {'Carpinteria, CA (CPN)': {'weight': 1}, 'Oxnard, CA (OXN)': {'weight': 1}}
# Camarillo, CA (CML)
# 	 {'Oxnard, CA (OXN)': {'weight': 1}, 'Moorpark, CA (MPK)': {'weight': 1}}
# Moorpark, CA (MPK)
# 	 {'Camarillo, CA (CML)': {'weight': 1}, 'Simi Valley, CA (SIM)': {'weight': 1}}
# Chatsworth, CA (CWT)
# 	 {'Simi Valley, CA (SIM)': {'weight': 1}, 'Northridge, CA (NRG)': {'weight': 1}}
# Northridge, CA (NRG)
# 	 {'Chatsworth, CA (CWT)': {'weight': 1}, 'Van Nuys, CA (VNC)': {'weight': 1}}
# Burbank, CA - Downtown (BBK)
# 	 {'Burbank, CA (BUR)': {'weight': 1}, 'Glendale, CA (GDL)': {'weight': 1}}
# Glendale, CA (GDL)
# 	 {'Burbank, CA - Downtown (BBK)': {'weight': 1}, 'Los Angeles, CA - Union Station (LAX)': {'weight': 1}}
# Fullerton, CA (FUL)
# 	 {'Los Angeles, CA - Union Station (LAX)': {'weight': 2}, 'Anaheim, CA - Regional Trans.Intermodal Ctr. (ANA)': {'weight': 1}, 'Riverside, CA (RIV)': {'weight': 1}}
# Anaheim, CA - Regional Trans.Intermodal Ctr. (ANA)
# 	 {'Fullerton, CA (FUL)': {'weight': 1}, 'Santa Ana, CA (SNA)': {'weight': 1}}
# Santa Ana, CA (SNA)
# 	 {'Anaheim, CA - Regional Trans.Intermodal Ctr. (ANA)': {'weight': 1}, 'Irvine, CA (IRV)': {'weight': 1}}
# Irvine, CA (IRV)
# 	 {'Santa Ana, CA (SNA)': {'weight': 1}, 'San Juan Capistrano, CA (SNC)': {'weight': 1}}
# San Juan Capistrano, CA (SNC)
# 	 {'Irvine, CA (IRV)': {'weight': 1}, 'San Clemente Pier, CA (SNP)': {'weight': 1}}
# San Clemente Pier, CA (SNP)
# 	 {'San Juan Capistrano, CA (SNC)': {'weight': 1}, 'Oceanside, CA (OSD)': {'weight': 1}}
# Oceanside, CA (OSD)
# 	 {'San Clemente Pier, CA (SNP)': {'weight': 1}, 'Solana Beach, CA (SOL)': {'weight': 1}}
# Solana Beach, CA (SOL)
# 	 {'Oceanside, CA (OSD)': {'weight': 1}, 'San Diego, CA - Old Town Transportation Center (OLT)': {'weight': 1}}
# San Diego, CA - Old Town Transportation Center (OLT)
# 	 {'Solana Beach, CA (SOL)': {'weight': 1}, 'San Diego, CA - Santa Fe Depot (SAN)': {'weight': 1}}
# San Diego, CA - Santa Fe Depot (SAN)
# 	 {'San Diego, CA - Old Town Transportation Center (OLT)': {'weight': 1}}
# Lewistown, PA - Amtrak Station (LEW)
# 	 {'Harrisburg, PA (HAR)': {'weight': 1}, 'Huntingdon, PA (HGD)': {'weight': 1}}
# Huntingdon, PA (HGD)
# 	 {'Lewistown, PA - Amtrak Station (LEW)': {'weight': 1}, 'Tyrone, PA (TYR)': {'weight': 1}}
# Tyrone, PA (TYR)
# 	 {'Huntingdon, PA (HGD)': {'weight': 1}, 'Altoona, PA (ALT)': {'weight': 1}}
# Altoona, PA (ALT)
# 	 {'Tyrone, PA (TYR)': {'weight': 1}, 'Johnstown, PA (JST)': {'weight': 1}}
# Johnstown, PA (JST)
# 	 {'Altoona, PA (ALT)': {'weight': 1}, 'Latrobe, PA - Amtrak Station (LAB)': {'weight': 1}}
# Latrobe, PA - Amtrak Station (LAB)
# 	 {'Johnstown, PA (JST)': {'weight': 1}, 'Greensburg, PA - Amtrak Station (GNB)': {'weight': 1}}
# Greensburg, PA - Amtrak Station (GNB)
# 	 {'Latrobe, PA - Amtrak Station (LAB)': {'weight': 1}, 'Pittsburgh, PA - Union Station (PGH)': {'weight': 1}}
# Lodi, CA (LOD)
# 	 {'Sacramento, CA - Sacramento Valley Station (SAC)': {'weight': 1}, 'Stockton, CA - Robert J. Cabral Station (SKT)': {'weight': 1}}
# Stockton, CA - Robert J. Cabral Station (SKT)
# 	 {'Lodi, CA (LOD)': {'weight': 1}, 'Oakland, CA - Jack London Square Station (OKJ)': {'weight': 1}}
# Antioch-Pittsburg, CA (ACA)
# 	 {'Martinez, CA (MTZ)': {'weight': 1}, 'Stockton, CA - San Joaquin Street Station (SKN)': {'weight': 1}}
# Stockton, CA - San Joaquin Street Station (SKN)
# 	 {'Antioch-Pittsburg, CA (ACA)': {'weight': 1}, 'Modesto, CA (MOD)': {'weight': 1}}
# Modesto, CA (MOD)
# 	 {'Stockton, CA - San Joaquin Street Station (SKN)': {'weight': 1}, 'Turlock-Denair, CA (TRK)': {'weight': 1}}
# Turlock-Denair, CA (TRK)
# 	 {'Modesto, CA (MOD)': {'weight': 1}, 'Merced, CA (MCD)': {'weight': 1}}
# Merced, CA (MCD)
# 	 {'Turlock-Denair, CA (TRK)': {'weight': 1}, 'Madera, CA (MDR)': {'weight': 1}}
# Madera, CA (MDR)
# 	 {'Merced, CA (MCD)': {'weight': 1}, 'Fresno, CA (FNO)': {'weight': 1}}
# Fresno, CA (FNO)
# 	 {'Madera, CA (MDR)': {'weight': 1}, 'Hanford, CA (HNF)': {'weight': 1}}
# Hanford, CA (HNF)
# 	 {'Fresno, CA (FNO)': {'weight': 1}, 'Corcoran, CA (COC)': {'weight': 1}}
# Corcoran, CA (COC)
# 	 {'Hanford, CA (HNF)': {'weight': 1}, 'Wasco, CA (WAC)': {'weight': 1}}
# Wasco, CA (WAC)
# 	 {'Corcoran, CA (COC)': {'weight': 1}, 'Bakersfield, CA (BFD)': {'weight': 1}}
# Bakersfield, CA (BFD)
# 	 {'Wasco, CA (WAC)': {'weight': 1}}
# Fayetteville, NC (FAY)
# 	 {'Raleigh, NC - Union Station (RGH)': {'weight': 1}, 'Dillon, SC (DIL)': {'weight': 1}}
# Dillon, SC (DIL)
# 	 {'Fayetteville, NC (FAY)': {'weight': 1}, 'Florence, SC (FLO)': {'weight': 1}}
# Florence, SC (FLO)
# 	 {'Dillon, SC (DIL)': {'weight': 1}, 'Kingstree, SC (KTR)': {'weight': 1}}
# Kingstree, SC (KTR)
# 	 {'Florence, SC (FLO)': {'weight': 1}, 'Charleston, SC (CHS)': {'weight': 1}}
# Charleston, SC (CHS)
# 	 {'Kingstree, SC (KTR)': {'weight': 1}, 'Yemassee, SC (YEM)': {'weight': 1}}
# Yemassee, SC (YEM)
# 	 {'Charleston, SC (CHS)': {'weight': 1}, 'Cary, NC (CYN)': {'weight': 1}}
# Southern Pines, NC (SOP)
# 	 {'Cary, NC (CYN)': {'weight': 1}, 'Hamlet, NC (HAM)': {'weight': 1}}
# Hamlet, NC (HAM)
# 	 {'Southern Pines, NC (SOP)': {'weight': 1}, 'Camden, SC (CAM)': {'weight': 1}}
# Camden, SC (CAM)
# 	 {'Hamlet, NC (HAM)': {'weight': 1}, 'Columbia, SC (CLB)': {'weight': 1}}
# Columbia, SC (CLB)
# 	 {'Camden, SC (CAM)': {'weight': 1}, 'Denmark, SC (DNK)': {'weight': 1}}
# Denmark, SC (DNK)
# 	 {'Columbia, SC (CLB)': {'weight': 1}, 'Savannah, GA (SAV)': {'weight': 1}}
# Savannah, GA (SAV)
# 	 {'Denmark, SC (DNK)': {'weight': 1}, 'Jesup, GA (JSP)': {'weight': 1}}
# Jesup, GA (JSP)
# 	 {'Savannah, GA (SAV)': {'weight': 1}, 'Jacksonville, FL (JAX)': {'weight': 1}}
# Jacksonville, FL (JAX)
# 	 {'Jesup, GA (JSP)': {'weight': 1}, 'Palatka, FL (PAK)': {'weight': 1}}
# Palatka, FL (PAK)
# 	 {'Jacksonville, FL (JAX)': {'weight': 1}, 'DeLand, FL (DLD)': {'weight': 1}}
# DeLand, FL (DLD)
# 	 {'Palatka, FL (PAK)': {'weight': 1}, 'Winter Park, FL (WPK)': {'weight': 1}}
# Winter Park, FL (WPK)
# 	 {'DeLand, FL (DLD)': {'weight': 1}, 'Orlando, FL (ORL)': {'weight': 1}}
# Orlando, FL (ORL)
# 	 {'Winter Park, FL (WPK)': {'weight': 1}, 'Kissimmee, FL (KIS)': {'weight': 1}}
# Kissimmee, FL (KIS)
# 	 {'Orlando, FL (ORL)': {'weight': 1}, 'Tampa, FL - Union Station (TPA)': {'weight': 1}}
# Tampa, FL - Union Station (TPA)
# 	 {'Kissimmee, FL (KIS)': {'weight': 1}, 'Lakeland, FL - To/from points south (LKL)': {'weight': 1}}
# Lakeland, FL - To/from points south (LKL)
# 	 {'Tampa, FL - Union Station (TPA)': {'weight': 1}, 'Lakeland, FL - To/from points north (LAK)': {'weight': 1}}
# Lakeland, FL - To/from points north (LAK)
# 	 {'Lakeland, FL - To/from points south (LKL)': {'weight': 1}, 'Winter Haven, FL (WTH)': {'weight': 1}}
# Winter Haven, FL (WTH)
# 	 {'Lakeland, FL - To/from points north (LAK)': {'weight': 1}, 'Sebring, FL (SBG)': {'weight': 1}}
# Sebring, FL (SBG)
# 	 {'Winter Haven, FL (WTH)': {'weight': 1}, 'Okeechobee, FL (OKE)': {'weight': 1}}
# Okeechobee, FL (OKE)
# 	 {'Sebring, FL (SBG)': {'weight': 1}, 'West Palm Beach, FL (WPB)': {'weight': 1}}
# West Palm Beach, FL (WPB)
# 	 {'Okeechobee, FL (OKE)': {'weight': 1}, 'Delray Beach, FL (DLB)': {'weight': 1}}
# Delray Beach, FL (DLB)
# 	 {'West Palm Beach, FL (WPB)': {'weight': 1}, 'Fort Lauderdale, FL (FTL)': {'weight': 1}}
# Fort Lauderdale, FL (FTL)
# 	 {'Delray Beach, FL (DLB)': {'weight': 1}, 'Hollywood, FL (HOL)': {'weight': 1}}
# Hollywood, FL (HOL)
# 	 {'Fort Lauderdale, FL (FTL)': {'weight': 1}, 'Miami, FL (MIA)': {'weight': 1}}
# Miami, FL (MIA)
# 	 {'Hollywood, FL (HOL)': {'weight': 1}}
# Fort Madison, IA (FMD)
# 	 {'Galesburg, IL (GBB)': {'weight': 1}, 'La Plata, MO (LAP)': {'weight': 1}}
# La Plata, MO (LAP)
# 	 {'Fort Madison, IA (FMD)': {'weight': 1}, 'Kansas City, MO - Union Station (KCY)': {'weight': 1}}
# Lawrence, KS (LRC)
# 	 {'Kansas City, MO - Union Station (KCY)': {'weight': 1}, 'Topeka, KS (TOP)': {'weight': 1}}
# Topeka, KS (TOP)
# 	 {'Lawrence, KS (LRC)': {'weight': 1}, 'Newton, KS (NEW)': {'weight': 1}}
# Newton, KS (NEW)
# 	 {'Topeka, KS (TOP)': {'weight': 1}, 'Hutchinson, KS (HUT)': {'weight': 1}}
# Hutchinson, KS (HUT)
# 	 {'Newton, KS (NEW)': {'weight': 1}, 'Dodge City, KS (DDG)': {'weight': 1}}
# Dodge City, KS (DDG)
# 	 {'Hutchinson, KS (HUT)': {'weight': 1}, 'Garden City, KS (GCK)': {'weight': 1}}
# Garden City, KS (GCK)
# 	 {'Dodge City, KS (DDG)': {'weight': 1}, 'Lamar, CO (LMR)': {'weight': 1}}
# Lamar, CO (LMR)
# 	 {'Garden City, KS (GCK)': {'weight': 1}, 'La Junta, CO (LAJ)': {'weight': 1}}
# La Junta, CO (LAJ)
# 	 {'Lamar, CO (LMR)': {'weight': 1}, 'Trinidad, CO (TRI)': {'weight': 1}}
# Trinidad, CO (TRI)
# 	 {'La Junta, CO (LAJ)': {'weight': 1}, 'Raton, NM (RAT)': {'weight': 1}}
# Raton, NM (RAT)
# 	 {'Trinidad, CO (TRI)': {'weight': 1}, 'Las Vegas, NM (LSV)': {'weight': 1}}
# Las Vegas, NM (LSV)
# 	 {'Raton, NM (RAT)': {'weight': 1}, 'Lamy, NM (LMY)': {'weight': 1}}
# Lamy, NM (LMY)
# 	 {'Las Vegas, NM (LSV)': {'weight': 1}, 'Albuquerque, NM (ABQ)': {'weight': 1}}
# Albuquerque, NM (ABQ)
# 	 {'Lamy, NM (LMY)': {'weight': 1}, 'Gallup, NM (GLP)': {'weight': 1}}
# Gallup, NM (GLP)
# 	 {'Albuquerque, NM (ABQ)': {'weight': 1}, 'Winslow, AZ (WLO)': {'weight': 1}}
# Winslow, AZ (WLO)
# 	 {'Gallup, NM (GLP)': {'weight': 1}, 'Flagstaff, AZ - Amtrak Station (FLG)': {'weight': 1}}
# Flagstaff, AZ - Amtrak Station (FLG)
# 	 {'Winslow, AZ (WLO)': {'weight': 1}, 'Kingman, AZ (KNG)': {'weight': 1}}
# Kingman, AZ (KNG)
# 	 {'Flagstaff, AZ - Amtrak Station (FLG)': {'weight': 1}, 'Needles, CA (NDL)': {'weight': 1}}
# Needles, CA (NDL)
# 	 {'Kingman, AZ (KNG)': {'weight': 1}, 'Barstow, CA - Harvey House Railroad Depot (BAR)': {'weight': 1}}
# Barstow, CA - Harvey House Railroad Depot (BAR)
# 	 {'Needles, CA (NDL)': {'weight': 1}, 'Victorville, CA - Amtrak Station (VRV)': {'weight': 1}}
# Victorville, CA - Amtrak Station (VRV)
# 	 {'Barstow, CA - Harvey House Railroad Depot (BAR)': {'weight': 1}, 'San Bernardino, CA (SNB)': {'weight': 1}}
# San Bernardino, CA (SNB)
# 	 {'Victorville, CA - Amtrak Station (VRV)': {'weight': 1}, 'Riverside, CA (RIV)': {'weight': 1}}
# Riverside, CA (RIV)
# 	 {'San Bernardino, CA (SNB)': {'weight': 1}, 'Fullerton, CA (FUL)': {'weight': 1}}
# Schriever, LA (SCH)
# 	 {'New Orleans, LA - Union Passenger Terminal (NOL)': {'weight': 1}, 'New Iberia, LA (NIB)': {'weight': 1}}
# New Iberia, LA (NIB)
# 	 {'Schriever, LA (SCH)': {'weight': 1}, 'Lafayette, LA (LFT)': {'weight': 1}}
# Lafayette, LA (LFT)
# 	 {'New Iberia, LA (NIB)': {'weight': 1}, 'Lake Charles, LA (LCH)': {'weight': 1}}
# Lake Charles, LA (LCH)
# 	 {'Lafayette, LA (LFT)': {'weight': 1}, 'Beaumont, TX (BMT)': {'weight': 1}}
# Beaumont, TX (BMT)
# 	 {'Lake Charles, LA (LCH)': {'weight': 1}, 'Houston, TX - Amtrak Station (HOS)': {'weight': 1}}
# Houston, TX - Amtrak Station (HOS)
# 	 {'Beaumont, TX (BMT)': {'weight': 1}, 'San Antonio, TX (SAS)': {'weight': 1}}
# San Antonio, TX (SAS)
# 	 {'Houston, TX - Amtrak Station (HOS)': {'weight': 1}, 'Del Rio, TX (DRT)': {'weight': 2}, 'San Marcos, TX (SMC)': {'weight': 1}}
# Del Rio, TX (DRT)
# 	 {'San Antonio, TX (SAS)': {'weight': 2}, 'Sanderson, TX (SND)': {'weight': 2}}
# Sanderson, TX (SND)
# 	 {'Del Rio, TX (DRT)': {'weight': 2}, 'Alpine, TX (ALP)': {'weight': 2}}
# Alpine, TX (ALP)
# 	 {'Sanderson, TX (SND)': {'weight': 2}, 'El Paso, TX - Union Depot (ELP)': {'weight': 2}}
# El Paso, TX - Union Depot (ELP)
# 	 {'Alpine, TX (ALP)': {'weight': 2}, 'Deming, NM (DEM)': {'weight': 2}}
# Deming, NM (DEM)
# 	 {'El Paso, TX - Union Depot (ELP)': {'weight': 2}, 'Lordsburg, NM (LDB)': {'weight': 2}}
# Lordsburg, NM (LDB)
# 	 {'Deming, NM (DEM)': {'weight': 2}, 'Benson, AZ (BEN)': {'weight': 2}}
# Benson, AZ (BEN)
# 	 {'Lordsburg, NM (LDB)': {'weight': 2}, 'Tucson, AZ (TUS)': {'weight': 2}}
# Tucson, AZ (TUS)
# 	 {'Benson, AZ (BEN)': {'weight': 2}, 'Maricopa, AZ (MRC)': {'weight': 2}}
# Maricopa, AZ (MRC)
# 	 {'Tucson, AZ (TUS)': {'weight': 2}, 'Yuma, AZ (YUM)': {'weight': 2}}
# Yuma, AZ (YUM)
# 	 {'Maricopa, AZ (MRC)': {'weight': 2}, 'Palm Springs, CA - Amtrak Station (PSN)': {'weight': 2}}
# Palm Springs, CA - Amtrak Station (PSN)
# 	 {'Yuma, AZ (YUM)': {'weight': 2}, 'Ontario, CA (ONA)': {'weight': 2}}
# Ontario, CA (ONA)
# 	 {'Palm Springs, CA - Amtrak Station (PSN)': {'weight': 2}, 'Pomona, CA (POS)': {'weight': 2}}
# Pomona, CA (POS)
# 	 {'Ontario, CA (ONA)': {'weight': 2}, 'Los Angeles, CA - Union Station (LAX)': {'weight': 2}}
# Arcadia, MO (ACD)
# 	 {'St. Louis, MO - Gateway Station (STL)': {'weight': 1}, 'Poplar Bluff, MO (PBF)': {'weight': 1}}
# Poplar Bluff, MO (PBF)
# 	 {'Arcadia, MO (ACD)': {'weight': 1}, 'Walnut Ridge, AR (WNR)': {'weight': 1}}
# Walnut Ridge, AR (WNR)
# 	 {'Poplar Bluff, MO (PBF)': {'weight': 1}, 'Little Rock, AR - Union Station (LRK)': {'weight': 1}}
# Little Rock, AR - Union Station (LRK)
# 	 {'Walnut Ridge, AR (WNR)': {'weight': 1}, 'Malvern, AR (MVN)': {'weight': 1}}
# Malvern, AR (MVN)
# 	 {'Little Rock, AR - Union Station (LRK)': {'weight': 1}, 'Arkadelphia, AR (ARK)': {'weight': 1}}
# Arkadelphia, AR (ARK)
# 	 {'Malvern, AR (MVN)': {'weight': 1}, 'Hope, AR (HOP)': {'weight': 1}}
# Hope, AR (HOP)
# 	 {'Arkadelphia, AR (ARK)': {'weight': 1}, 'Texarkana, AR (TXA)': {'weight': 1}}
# Texarkana, AR (TXA)
# 	 {'Hope, AR (HOP)': {'weight': 1}, 'Marshall, TX (MHL)': {'weight': 1}}
# Marshall, TX (MHL)
# 	 {'Texarkana, AR (TXA)': {'weight': 1}, 'Longview, TX (LVW)': {'weight': 1}}
# Longview, TX (LVW)
# 	 {'Marshall, TX (MHL)': {'weight': 1}, 'Mineola, TX (MIN)': {'weight': 1}}
# Mineola, TX (MIN)
# 	 {'Longview, TX (LVW)': {'weight': 1}, 'Dallas, TX - Eddie Bernice Johnson Union Station (DAL)': {'weight': 1}}
# Dallas, TX - Eddie Bernice Johnson Union Station (DAL)
# 	 {'Mineola, TX (MIN)': {'weight': 1}, 'Fort Worth, TX (FTW)': {'weight': 1}}
# Cleburne, TX (CBR)
# 	 {'Fort Worth, TX (FTW)': {'weight': 1}, 'McGregor, TX (MCG)': {'weight': 1}}
# McGregor, TX (MCG)
# 	 {'Cleburne, TX (CBR)': {'weight': 1}, 'Temple, TX (TPL)': {'weight': 1}}
# Temple, TX (TPL)
# 	 {'McGregor, TX (MCG)': {'weight': 1}, 'Taylor, TX (TAY)': {'weight': 1}}
# Taylor, TX (TAY)
# 	 {'Temple, TX (TPL)': {'weight': 1}, 'Austin, TX (AUS)': {'weight': 1}}
# Austin, TX (AUS)
# 	 {'Taylor, TX (TAY)': {'weight': 1}, 'San Marcos, TX (SMC)': {'weight': 1}}
# San Marcos, TX (SMC)
# 	 {'Austin, TX (AUS)': {'weight': 1}, 'San Antonio, TX (SAS)': {'weight': 1}}
# Greenfield, MA (GFD)
# 	 {'Northampton, MA (NHT)': {'weight': 2}, 'Brattleboro, VT (BRA)': {'weight': 1}}
# Northampton, MA (NHT)
# 	 {'Greenfield, MA (GFD)': {'weight': 2}, 'Holyoke, MA (HLK)': {'weight': 2}}
# Holyoke, MA (HLK)
# 	 {'Northampton, MA (NHT)': {'weight': 2}, 'Springfield, MA (SPG)': {'weight': 2}}
# St. Albans, VT (SAB)
# 	 {'Essex Junction-Burlington, VT (ESX)': {'weight': 1}}
# Essex Junction-Burlington, VT (ESX)
# 	 {'St. Albans, VT (SAB)': {'weight': 1}, 'Waterbury-Stowe, VT (WAB)': {'weight': 1}}
# Waterbury-Stowe, VT (WAB)
# 	 {'Essex Junction-Burlington, VT (ESX)': {'weight': 1}, 'Montpelier-Berlin, VT (MPR)': {'weight': 1}}
# Montpelier-Berlin, VT (MPR)
# 	 {'Waterbury-Stowe, VT (WAB)': {'weight': 1}, 'Randolph, VT (RPH)': {'weight': 1}}
# Randolph, VT (RPH)
# 	 {'Montpelier-Berlin, VT (MPR)': {'weight': 1}, 'White River Junction, VT (WRJ)': {'weight': 1}}
# White River Junction, VT (WRJ)
# 	 {'Randolph, VT (RPH)': {'weight': 1}, 'Windsor-Mt. Ascutney, VT (WNM)': {'weight': 1}}
# Windsor-Mt. Ascutney, VT (WNM)
# 	 {'White River Junction, VT (WRJ)': {'weight': 1}, 'Claremont, NH (CLA)': {'weight': 1}}
# Claremont, NH (CLA)
# 	 {'Windsor-Mt. Ascutney, VT (WNM)': {'weight': 1}, 'Bellows Falls, VT (BLF)': {'weight': 1}}
# Bellows Falls, VT (BLF)
# 	 {'Claremont, NH (CLA)': {'weight': 1}, 'Brattleboro, VT (BRA)': {'weight': 1}}
# Brattleboro, VT (BRA)
# 	 {'Bellows Falls, VT (BLF)': {'weight': 1}, 'Greenfield, MA (GFD)': {'weight': 1}}

# %%
for node in G_induced_cities.nodes():
    print('%s\t'%(node),G_induced_cities[node])
# Out:
# New York, NY	 {'Stamford, CT': {'weight': 2}, 'Newark, NJ': {'weight': 9}, 'Yonkers, NY': {'weight': 5}}
# Los Angeles, CA	 {'Burbank, CA': {'weight': 1}, 'Glendale, CA': {'weight': 1}, 'Fullerton, CA': {'weight': 2}, 'Pomona, CA': {'weight': 2}}
# Chicago, IL	 {'Naperville, IL': {'weight': 2}, 'South Bend, IN': {'weight': 2}, 'Joliet, IL': {'weight': 1}}
# Houston, TX	 {'Beaumont, TX': {'weight': 1}, 'San Antonio, TX': {'weight': 1}}
# Phoenix, AZ	 {}
# Philadelphia, PA	 {'Philadelphia, PA': {'weight': 6}}
# San Antonio, TX	 {'Houston, TX': {'weight': 1}}
# San Diego, CA	 {'San Diego, CA': {'weight': 2}}
# Dallas, TX	 {'Fort Worth, TX': {'weight': 1}}
# San Jose, CA	 {'Oakland, CA': {'weight': 1}, 'Santa Clara, CA': {'weight': 1}, 'Salinas, CA': {'weight': 1}}
# Austin, TX	 {}
# Jacksonville, FL	 {}
# Fort Worth, TX	 {'Dallas, TX': {'weight': 1}}
# Columbus, OH	 {}
# Indianapolis, IN	 {}
# Charlotte, NC	 {}
# San Francisco, CA	 {}
# Seattle, WA	 {'Tacoma, WA': {'weight': 1}}
# Denver, CO	 {}
# Oklahoma City, OK	 {'Norman, OK': {'weight': 1}}
# Nashville, TN	 {}
# El Paso, TX	 {}
# Washington, DC	 {'Baltimore, MD': {'weight': 4}, 'Alexandria, VA': {'weight': 5}}
# Boston, MA	 {'Boston, MA': {'weight': 6}}
# Las Vegas, NV	 {}
# Portland, OR	 {'Salem, OR': {'weight': 1}, 'Vancouver, WA': {'weight': 3}}
# Detroit, MI	 {'Dearborn, MI': {'weight': 1}}
# Louisville, KY	 {}
# Memphis, TN	 {}
# Baltimore, MD	 {'Baltimore, MD': {'weight': 8}, 'Washington, DC': {'weight': 4}}
# Milwaukee, WI	 {'Milwaukee, WI': {'weight': 2}}
# Albuquerque, NM	 {}
# Fresno, CA	 {}
# Tucson, AZ	 {}
# Sacramento, CA	 {'Roseville, CA': {'weight': 2}, 'Chico, CA': {'weight': 1}}
# Mesa, AZ	 {}
# Kansas City, MO	 {'Independence, MO': {'weight': 2}}
# Atlanta, GA	 {}
# Omaha, NE	 {'Lincoln, NE': {'weight': 1}}
# Colorado Springs, CO	 {}
# Raleigh, NC	 {'Cary, NC': {'weight': 1}, 'Fayetteville, NC': {'weight': 1}}
# Virginia Beach, VA	 {}
# Long Beach, CA	 {}
# Miami, FL	 {'Hollywood, FL': {'weight': 1}}
# Oakland, CA	 {'Oakland, CA': {'weight': 2}, 'San Jose, CA': {'weight': 1}, 'Stockton, CA': {'weight': 1}, 'Hayward, CA': {'weight': 1}}
# Minneapolis, MN	 {}
# Tulsa, OK	 {}
# Bakersfield, CA	 {}
# Wichita, KS	 {}
# Arlington, TX	 {}
# Aurora, CO	 {}
# Tampa, FL	 {'Lakeland, FL': {'weight': 1}}
# New Orleans, LA	 {}
# Cleveland, OH	 {}
# Anaheim, CA	 {'Fullerton, CA': {'weight': 1}, 'Santa Ana, CA': {'weight': 1}}
# Honolulu, HI	 {}
# Henderson, NV	 {}
# Stockton, CA	 {'Oakland, CA': {'weight': 1}, 'Modesto, CA': {'weight': 1}}
# Lexington, KY	 {}
# Corpus Christi, TX	 {}
# Riverside, CA	 {'Fullerton, CA': {'weight': 1}, 'San Bernardino, CA': {'weight': 1}}
# Santa Ana, CA	 {'Anaheim, CA': {'weight': 1}, 'Irvine, CA': {'weight': 1}}
# Orlando, FL	 {}
# Irvine, CA	 {'Santa Ana, CA': {'weight': 1}}
# Cincinnati, OH	 {}
# Newark, NJ	 {'New York, NY': {'weight': 9}, 'Newark, NJ': {'weight': 6}}
# Saint Paul, MN	 {}
# Pittsburgh, PA	 {}
# Greensboro, NC	 {'High Point, NC': {'weight': 2}}
# St. Louis, MO	 {}
# Lincoln, NE	 {'Omaha, NE': {'weight': 1}}
# Plano, TX	 {}
# Anchorage, AK	 {}
# Durham, NC	 {'Cary, NC': {'weight': 1}}
# Jersey City, NJ	 {}
# Chandler, AZ	 {}
# Chula Vista, CA	 {}
# Buffalo, NY	 {'Buffalo, NY': {'weight': 4}, 'Rochester, NY': {'weight': 3}}
# North Las Vegas, NV	 {}
# Gilbert, AZ	 {}
# Madison, WI	 {}
# Reno, NV	 {}
# Toledo, OH	 {}
# Fort Wayne, IN	 {}
# Lubbock, TX	 {}
# St. Petersburg, FL	 {}
# Laredo, TX	 {}
# Irving, TX	 {}
# Chesapeake, VA	 {}
# Winston–Salem, NC	 {}
# Glendale, AZ	 {}
# Scottsdale, AZ	 {}
# Garland, TX	 {}
# Boise, ID	 {}
# Norfolk, VA	 {'Richmond, VA': {'weight': 1}}
# Spokane, WA	 {}
# Fremont, CA	 {'Hayward, CA': {'weight': 1}, 'Santa Clara, CA': {'weight': 1}}
# Richmond, VA	 {'Norfolk, VA': {'weight': 1}}
# Santa Clarita, CA	 {}
# San Bernardino, CA	 {'Victorville, CA': {'weight': 1}, 'Riverside, CA': {'weight': 1}}
# Baton Rouge, LA	 {}
# Hialeah, FL	 {}
# Tacoma, WA	 {'Seattle, WA': {'weight': 1}}
# Modesto, CA	 {'Stockton, CA': {'weight': 1}}
# Port St. Lucie, FL	 {}
# Huntsville, AL	 {}
# Des Moines, IA	 {}
# Moreno Valley, CA	 {}
# Fontana, CA	 {}
# Frisco, TX	 {}
# Rochester, NY	 {'Buffalo, NY': {'weight': 3}, 'Syracuse, NY': {'weight': 3}}
# Yonkers, NY	 {'New York, NY': {'weight': 5}}
# Fayetteville, NC	 {'Raleigh, NC': {'weight': 1}}
# Worcester, MA	 {'Springfield, MA': {'weight': 1}}
# Columbus, GA	 {}
# Cape Coral, FL	 {}
# McKinney, TX	 {}
# Little Rock, AR	 {}
# Oxnard, CA	 {'Simi Valley, CA': {'weight': 1}}
# Amarillo, TX	 {}
# Augusta, GA	 {}
# Salt Lake City, UT	 {'Provo, UT': {'weight': 1}}
# Montgomery, AL	 {}
# Birmingham, AL	 {'Tuscaloosa, AL': {'weight': 1}}
# Grand Rapids, MI	 {}
# Grand Prairie, TX	 {}
# Overland Park, KS	 {}
# Tallahassee, FL	 {}
# Huntington Beach, CA	 {}
# Sioux Falls, SD	 {}
# Peoria, AZ	 {}
# Knoxville, TN	 {}
# Glendale, CA	 {'Los Angeles, CA': {'weight': 1}, 'Burbank, CA': {'weight': 1}}
# Vancouver, WA	 {'Portland, OR': {'weight': 3}}
# Providence, RI	 {'New Haven, CT': {'weight': 1}}
# Akron, OH	 {}
# Brownsville, TX	 {}
# Mobile, AL	 {}
# Newport News, VA	 {}
# Tempe, AZ	 {}
# Shreveport, LA	 {}
# Chattanooga, TN	 {}
# Fort Lauderdale, FL	 {'Hollywood, FL': {'weight': 1}}
# Aurora, IL	 {}
# Elk Grove, CA	 {}
# Ontario, CA	 {'Pomona, CA': {'weight': 2}}
# Salem, OR	 {'Portland, OR': {'weight': 1}}
# Cary, NC	 {'Raleigh, NC': {'weight': 1}, 'Durham, NC': {'weight': 1}}
# Santa Rosa, CA	 {}
# Rancho Cucamonga, CA	 {}
# Eugene, OR	 {}
# Oceanside, CA	 {}
# Clarksville, TN	 {}
# Garden Grove, CA	 {}
# Lancaster, CA	 {}
# Springfield, MO	 {}
# Pembroke Pines, FL	 {}
# Fort Collins, CO	 {}
# Palmdale, CA	 {}
# Salinas, CA	 {'San Jose, CA': {'weight': 1}}
# Hayward, CA	 {'Oakland, CA': {'weight': 1}, 'Fremont, CA': {'weight': 1}}
# Corona, CA	 {}
# Paterson, NJ	 {}
# Murfreesboro, TN	 {}
# Macon, GA	 {}
# Lakewood, CO	 {}
# Killeen, TX	 {}
# Springfield, MA	 {'Worcester, MA': {'weight': 1}}
# Alexandria, VA	 {'Washington, DC': {'weight': 5}}
# Kansas City, KS	 {}
# Sunnyvale, CA	 {}
# Hollywood, FL	 {'Fort Lauderdale, FL': {'weight': 1}, 'Miami, FL': {'weight': 1}}
# Roseville, CA	 {'Sacramento, CA': {'weight': 2}}
# Charleston, SC	 {}
# Escondido, CA	 {}
# Joliet, IL	 {'Chicago, IL': {'weight': 1}}
# Jackson, MS	 {}
# Bellevue, WA	 {}
# Surprise, AZ	 {}
# Naperville, IL	 {'Chicago, IL': {'weight': 2}}
# Pasadena, TX	 {}
# Pomona, CA	 {'Los Angeles, CA': {'weight': 2}, 'Ontario, CA': {'weight': 2}}
# Bridgeport, CT	 {'New Haven, CT': {'weight': 2}, 'Stamford, CT': {'weight': 2}}
# Denton, TX	 {}
# Rockford, IL	 {}
# Mesquite, TX	 {}
# Savannah, GA	 {}
# Syracuse, NY	 {'Rochester, NY': {'weight': 3}}
# McAllen, TX	 {}
# Torrance, CA	 {}
# Olathe, KS	 {}
# Visalia, CA	 {}
# Thornton, CO	 {}
# Fullerton, CA	 {'Los Angeles, CA': {'weight': 2}, 'Anaheim, CA': {'weight': 1}, 'Riverside, CA': {'weight': 1}}
# Gainesville, FL	 {}
# Waco, TX	 {}
# West Valley City, UT	 {}
# Warren, MI	 {}
# Lakewood, NJ	 {}
# Hampton, VA	 {}
# Dayton, OH	 {}
# Columbia, SC	 {}
# Orange, CA	 {}
# Cedar Rapids, IA	 {}
# Stamford, CT	 {'New Haven, CT': {'weight': 1}, 'New York, NY': {'weight': 2}, 'Bridgeport, CT': {'weight': 2}}
# Victorville, CA	 {'San Bernardino, CA': {'weight': 1}}
# Pasadena, CA	 {}
# Elizabeth, NJ	 {}
# New Haven, CT	 {'Providence, RI': {'weight': 1}, 'Stamford, CT': {'weight': 1}, 'New Haven, CT': {'weight': 6}, 'Bridgeport, CT': {'weight': 2}}
# Miramar, FL	 {}
# Kent, WA	 {}
# Sterling Heights, MI	 {}
# Carrollton, TX	 {}
# Coral Springs, FL	 {}
# Midland, TX	 {}
# Norman, OK	 {'Oklahoma City, OK': {'weight': 1}}
# Athens, GA	 {}
# Santa Clara, CA	 {'Fremont, CA': {'weight': 1}, 'Santa Clara, CA': {'weight': 2}, 'San Jose, CA': {'weight': 1}}
# Columbia, MO	 {}
# Fargo, ND	 {}
# Pearland, TX	 {}
# Simi Valley, CA	 {'Oxnard, CA': {'weight': 1}}
# Meridian, ID	 {}
# Topeka, KS	 {}
# Allentown, PA	 {}
# Thousand Oaks, CA	 {}
# Abilene, TX	 {}
# Vallejo, CA	 {}
# Concord, CA	 {}
# Round Rock, TX	 {}
# Arvada, CO	 {}
# Clovis, CA	 {}
# Palm Bay, FL	 {}
# Independence, MO	 {"Lee's Summit, MO": {'weight': 2}, 'Kansas City, MO': {'weight': 2}}
# Lafayette, LA	 {}
# Ann Arbor, MI	 {'Dearborn, MI': {'weight': 1}}
# Rochester, MN	 {}
# Hartford, CT	 {}
# College Station, TX	 {}
# Fairfield, CA	 {'Vacaville, CA': {'weight': 1}}
# Wilmington, NC	 {}
# North Charleston, SC	 {}
# Billings, MT	 {}
# West Palm Beach, FL	 {}
# Berkeley, CA	 {'Richmond, CA': {'weight': 1}}
# Cambridge, MA	 {}
# Clearwater, FL	 {}
# West Jordan, UT	 {}
# Evansville, IN	 {}
# Richardson, TX	 {}
# Broken Arrow, OK	 {}
# Richmond, CA	 {'Berkeley, CA': {'weight': 1}}
# League City, TX	 {}
# Manchester, NH	 {}
# Lakeland, FL	 {'Tampa, FL': {'weight': 1}, 'Lakeland, FL': {'weight': 2}}
# Carlsbad, CA	 {}
# Antioch, CA	 {}
# Westminster, CO	 {}
# High Point, NC	 {'Greensboro, NC': {'weight': 2}}
# Provo, UT	 {'Salt Lake City, UT': {'weight': 1}}
# Lowell, MA	 {}
# Elgin, IL	 {}
# Waterbury, CT	 {}
# Springfield, IL	 {}
# Gresham, OR	 {}
# Murrieta, CA	 {}
# Lewisville, TX	 {}
# Las Cruces, NM	 {}
# Lansing, MI	 {}
# Beaumont, TX	 {'Houston, TX': {'weight': 1}}
# Odessa, TX	 {}
# Pueblo, CO	 {}
# Peoria, IL	 {}
# Downey, CA	 {}
# Pompano Beach, FL	 {}
# Miami Gardens, FL	 {}
# Temecula, CA	 {}
# Everett, WA	 {}
# Costa Mesa, CA	 {}
# Ventura[, CA	 {}
# Sparks, NV	 {}
# Santa Maria, CA	 {}
# Sugar Land, TX	 {}
# Greeley, CO	 {}
# South Fulton, GA	 {}
# Dearborn, MI	 {'Ann Arbor, MI': {'weight': 1}, 'Detroit, MI': {'weight': 1}}
# Concord, NC	 {}
# Edison, NJ	 {}
# Tyler, TX	 {}
# Sandy Springs, GA	 {}
# West Covina, CA	 {}
# Green Bay, WI	 {}
# Centennial, CO	 {}
# Jurupa Valley, CA	 {}
# El Monte, CA	 {}
# Allen, TX	 {}
# Hillsboro, OR	 {}
# Menifee, CA	 {}
# Nampa, ID	 {}
# Spokane Valley, WA	 {}
# Rio Rancho, NM	 {}
# Brockton, MA	 {}
# El Cajon, CA	 {}
# Burbank, CA	 {'Los Angeles, CA': {'weight': 1}, 'Burbank, CA': {'weight': 2}, 'Glendale, CA': {'weight': 1}}
# Inglewood, CA	 {}
# Renton, WA	 {}
# Davie, FL	 {}
# Rialto, CA	 {}
# Boulder, CO	 {}
# South Bend, IN	 {'Chicago, IL': {'weight': 2}}
# Woodbridge, NJ	 {}
# Vacaville, CA	 {'Fairfield, CA': {'weight': 1}}
# Wichita Falls, TX	 {}
# Lee's Summit, MO	 {'Independence, MO': {'weight': 2}}
# Edinburg, TX	 {}
# Chico, CA	 {'Sacramento, CA': {'weight': 1}}
# San Mateo, CA	 {}
# Bend, OR	 {}
# Goodyear, AZ	 {}
# Buckeye, AZ	 {}
# Daly City, CA	 {}
# Fishers, IN	 {}
# Quincy, MA	 {}
# Davenport, IA	 {}
# Hesperia, CA	 {}
# New Bedford, MA	 {}
# Lynn, MA	 {}
# Carmel, IN	 {}
# Longmont, CO	 {}
# Tuscaloosa, AL	 {'Birmingham, AL': {'weight': 1}}
# Norwalk, CA	 {}

# %%
for node in G_noninduced_cities.nodes():
    print('%s\t'%(node),G_noninduced_cities[node])
# Out:
# New York, NY	 {'Stamford, CT': {'weight': 3}, 'Newark, NJ': {'weight': 9}, 'Yonkers, NY': {'weight': 5}, 'Boston, MA': {'weight': 1}}
# Los Angeles, CA	 {'Burbank, CA': {'weight': 1}, 'Glendale, CA': {'weight': 1}, 'Fullerton, CA': {'weight': 2}, 'Pomona, CA': {'weight': 2}}
# Chicago, IL	 {'Naperville, IL': {'weight': 2}, 'South Bend, IN': {'weight': 2}, 'Indianapolis, IN': {'weight': 1}, 'Memphis, TN': {'weight': 1}, 'Milwaukee, WI': {'weight': 2}, 'Joliet, IL': {'weight': 3}, 'Lansing, MI': {'weight': 1}}
# Houston, TX	 {'Beaumont, TX': {'weight': 1}, 'San Antonio, TX': {'weight': 1}}
# Phoenix, AZ	 {}
# Philadelphia, PA	 {'Newark, NJ': {'weight': 9}, 'Baltimore, MD': {'weight': 7}, 'Philadelphia, PA': {'weight': 6}, 'Pittsburgh, PA': {'weight': 1}}
# San Antonio, TX	 {'Houston, TX': {'weight': 1}, 'El Paso, TX': {'weight': 2}, 'Austin, TX': {'weight': 1}}
# San Diego, CA	 {'Oceanside, CA': {'weight': 1}, 'San Diego, CA': {'weight': 2}}
# Dallas, TX	 {'Little Rock, AR': {'weight': 1}, 'Fort Worth, TX': {'weight': 1}}
# San Jose, CA	 {'Santa Clara, CA': {'weight': 1}, 'Oakland, CA': {'weight': 1}, 'Salinas, CA': {'weight': 1}}
# Austin, TX	 {'Fort Worth, TX': {'weight': 1}, 'San Antonio, TX': {'weight': 1}}
# Jacksonville, FL	 {'Savannah, GA': {'weight': 1}, 'Orlando, FL': {'weight': 1}}
# Fort Worth, TX	 {'Norman, OK': {'weight': 1}, 'Dallas, TX': {'weight': 1}, 'Austin, TX': {'weight': 1}}
# Columbus, OH	 {}
# Indianapolis, IN	 {'Cincinnati, OH': {'weight': 1}, 'Chicago, IL': {'weight': 1}}
# Charlotte, NC	 {'High Point, NC': {'weight': 2}, 'Atlanta, GA': {'weight': 1}}
# San Francisco, CA	 {}
# Seattle, WA	 {'Tacoma, WA': {'weight': 2}, 'Everett, WA': {'weight': 2}}
# Denver, CO	 {'Lincoln, NE': {'weight': 1}, 'Provo, UT': {'weight': 1}}
# Oklahoma City, OK	 {'Norman, OK': {'weight': 1}}
# Nashville, TN	 {}
# El Paso, TX	 {'San Antonio, TX': {'weight': 2}, 'Tucson, AZ': {'weight': 2}}
# Washington, DC	 {'Baltimore, MD': {'weight': 7}, 'Pittsburgh, PA': {'weight': 1}, 'Alexandria, VA': {'weight': 5}}
# Boston, MA	 {'Boston, MA': {'weight': 6}, 'Providence, RI': {'weight': 2}, 'Worcester, MA': {'weight': 1}, 'New York, NY': {'weight': 1}}
# Las Vegas, NV	 {}
# Portland, OR	 {'Salem, OR': {'weight': 2}, 'Vancouver, WA': {'weight': 3}, 'Everett, WA': {'weight': 1}}
# Detroit, MI	 {'Dearborn, MI': {'weight': 1}}
# Louisville, KY	 {}
# Memphis, TN	 {'Chicago, IL': {'weight': 1}, 'Jackson, MS': {'weight': 1}}
# Baltimore, MD	 {'Philadelphia, PA': {'weight': 7}, 'Baltimore, MD': {'weight': 8}, 'Washington, DC': {'weight': 7}}
# Milwaukee, WI	 {'Chicago, IL': {'weight': 2}, 'Minneapolis, MN': {'weight': 1}, 'Milwaukee, WI': {'weight': 2}}
# Albuquerque, NM	 {'Topeka, KS': {'weight': 1}, 'Victorville, CA': {'weight': 1}}
# Fresno, CA	 {'Modesto, CA': {'weight': 1}, 'Bakersfield, CA': {'weight': 1}}
# Tucson, AZ	 {'El Paso, TX': {'weight': 2}, 'Ontario, CA': {'weight': 2}}
# Sacramento, CA	 {'Roseville, CA': {'weight': 2}, 'Vacaville, CA': {'weight': 1}, 'Chico, CA': {'weight': 1}, 'Oakland, CA': {'weight': 1}, 'Stockton, CA': {'weight': 1}}
# Mesa, AZ	 {}
# Kansas City, MO	 {'Independence, MO': {'weight': 2}, 'Naperville, IL': {'weight': 1}, 'Topeka, KS': {'weight': 1}}
# Atlanta, GA	 {'Charlotte, NC': {'weight': 1}, 'Birmingham, AL': {'weight': 1}}
# Omaha, NE	 {'Naperville, IL': {'weight': 1}, 'Lincoln, NE': {'weight': 1}}
# Colorado Springs, CO	 {}
# Raleigh, NC	 {'Richmond, VA': {'weight': 2}, 'Cary, NC': {'weight': 1}, 'Fayetteville, NC': {'weight': 1}}
# Virginia Beach, VA	 {}
# Long Beach, CA	 {}
# Miami, FL	 {'Hollywood, FL': {'weight': 1}}
# Oakland, CA	 {'Berkeley, CA': {'weight': 1}, 'Oakland, CA': {'weight': 2}, 'Hayward, CA': {'weight': 1}, 'Sacramento, CA': {'weight': 1}, 'San Jose, CA': {'weight': 1}, 'Stockton, CA': {'weight': 1}, 'Richmond, CA': {'weight': 1}}
# Minneapolis, MN	 {'Milwaukee, WI': {'weight': 1}, 'Fargo, ND': {'weight': 1}}
# Tulsa, OK	 {}
# Bakersfield, CA	 {'Fresno, CA': {'weight': 1}}
# Wichita, KS	 {}
# Arlington, TX	 {}
# Aurora, CO	 {}
# Tampa, FL	 {'Orlando, FL': {'weight': 1}, 'Lakeland, FL': {'weight': 1}}
# New Orleans, LA	 {'Jackson, MS': {'weight': 1}, 'Lafayette, LA': {'weight': 1}}
# Cleveland, OH	 {'Pittsburgh, PA': {'weight': 1}, 'Toledo, OH': {'weight': 2}, 'Buffalo, NY': {'weight': 1}}
# Anaheim, CA	 {'Fullerton, CA': {'weight': 1}, 'Santa Ana, CA': {'weight': 1}}
# Honolulu, HI	 {}
# Henderson, NV	 {}
# Stockton, CA	 {'Sacramento, CA': {'weight': 1}, 'Oakland, CA': {'weight': 1}, 'Richmond, CA': {'weight': 1}, 'Modesto, CA': {'weight': 1}}
# Lexington, KY	 {}
# Corpus Christi, TX	 {}
# Riverside, CA	 {'San Bernardino, CA': {'weight': 1}, 'Fullerton, CA': {'weight': 1}}
# Santa Ana, CA	 {'Anaheim, CA': {'weight': 1}, 'Irvine, CA': {'weight': 1}}
# Orlando, FL	 {'Jacksonville, FL': {'weight': 1}, 'Tampa, FL': {'weight': 1}}
# Irvine, CA	 {'Santa Ana, CA': {'weight': 1}, 'Oceanside, CA': {'weight': 1}}
# Cincinnati, OH	 {'Alexandria, VA': {'weight': 1}, 'Indianapolis, IN': {'weight': 1}}
# Newark, NJ	 {'New York, NY': {'weight': 9}, 'Philadelphia, PA': {'weight': 9}, 'Newark, NJ': {'weight': 6}}
# Saint Paul, MN	 {}
# Pittsburgh, PA	 {'Washington, DC': {'weight': 1}, 'Cleveland, OH': {'weight': 1}, 'Philadelphia, PA': {'weight': 1}}
# Greensboro, NC	 {'Durham, NC': {'weight': 1}, 'High Point, NC': {'weight': 2}, 'Alexandria, VA': {'weight': 1}}
# St. Louis, MO	 {'Springfield, IL': {'weight': 2}, "Lee's Summit, MO": {'weight': 2}, 'Little Rock, AR': {'weight': 1}}
# Lincoln, NE	 {'Omaha, NE': {'weight': 1}, 'Denver, CO': {'weight': 1}}
# Plano, TX	 {}
# Anchorage, AK	 {}
# Durham, NC	 {'Cary, NC': {'weight': 1}, 'Greensboro, NC': {'weight': 1}}
# Jersey City, NJ	 {}
# Chandler, AZ	 {}
# Chula Vista, CA	 {}
# Buffalo, NY	 {'Buffalo, NY': {'weight': 4}, 'Rochester, NY': {'weight': 3}, 'Cleveland, OH': {'weight': 1}}
# North Las Vegas, NV	 {}
# Gilbert, AZ	 {}
# Madison, WI	 {}
# Reno, NV	 {'Salt Lake City, UT': {'weight': 1}, 'Roseville, CA': {'weight': 1}}
# Toledo, OH	 {'Cleveland, OH': {'weight': 2}, 'South Bend, IN': {'weight': 2}}
# Fort Wayne, IN	 {}
# Lubbock, TX	 {}
# St. Petersburg, FL	 {}
# Laredo, TX	 {}
# Irving, TX	 {}
# Chesapeake, VA	 {}
# Winston–Salem, NC	 {}
# Glendale, AZ	 {}
# Scottsdale, AZ	 {}
# Garland, TX	 {}
# Boise, ID	 {}
# Norfolk, VA	 {'Richmond, VA': {'weight': 2}}
# Spokane, WA	 {'Fargo, ND': {'weight': 1}, 'Vancouver, WA': {'weight': 1}}
# Fremont, CA	 {'Hayward, CA': {'weight': 1}, 'Santa Clara, CA': {'weight': 1}}
# Richmond, VA	 {'Alexandria, VA': {'weight': 3}, 'Raleigh, NC': {'weight': 2}, 'Norfolk, VA': {'weight': 2}, 'Newport News, VA': {'weight': 1}}
# Santa Clarita, CA	 {}
# San Bernardino, CA	 {'Victorville, CA': {'weight': 1}, 'Riverside, CA': {'weight': 1}}
# Baton Rouge, LA	 {}
# Hialeah, FL	 {}
# Tacoma, WA	 {'Vancouver, WA': {'weight': 2}, 'Seattle, WA': {'weight': 2}}
# Modesto, CA	 {'Stockton, CA': {'weight': 1}, 'Fresno, CA': {'weight': 1}}
# Port St. Lucie, FL	 {}
# Huntsville, AL	 {}
# Des Moines, IA	 {}
# Moreno Valley, CA	 {}
# Fontana, CA	 {}
# Frisco, TX	 {}
# Rochester, NY	 {'Buffalo, NY': {'weight': 3}, 'Syracuse, NY': {'weight': 3}}
# Yonkers, NY	 {'New York, NY': {'weight': 5}, 'Syracuse, NY': {'weight': 2}}
# Fayetteville, NC	 {'Raleigh, NC': {'weight': 1}, 'Charleston, SC': {'weight': 1}}
# Worcester, MA	 {'Springfield, MA': {'weight': 1}, 'Boston, MA': {'weight': 1}}
# Columbus, GA	 {}
# Cape Coral, FL	 {}
# McKinney, TX	 {}
# Little Rock, AR	 {'St. Louis, MO': {'weight': 1}, 'Dallas, TX': {'weight': 1}}
# Oxnard, CA	 {'Salinas, CA': {'weight': 1}, 'Simi Valley, CA': {'weight': 2}}
# Amarillo, TX	 {}
# Augusta, GA	 {}
# Salt Lake City, UT	 {'Provo, UT': {'weight': 1}, 'Reno, NV': {'weight': 1}}
# Montgomery, AL	 {}
# Birmingham, AL	 {'Atlanta, GA': {'weight': 1}, 'Tuscaloosa, AL': {'weight': 1}}
# Grand Rapids, MI	 {'Lansing, MI': {'weight': 1}, 'Ann Arbor, MI': {'weight': 1}}
# Grand Prairie, TX	 {}
# Overland Park, KS	 {}
# Tallahassee, FL	 {}
# Huntington Beach, CA	 {}
# Sioux Falls, SD	 {}
# Peoria, AZ	 {}
# Knoxville, TN	 {}
# Glendale, CA	 {'Burbank, CA': {'weight': 1}, 'Los Angeles, CA': {'weight': 1}}
# Vancouver, WA	 {'Portland, OR': {'weight': 3}, 'Tacoma, WA': {'weight': 2}, 'Spokane, WA': {'weight': 1}}
# Providence, RI	 {'Boston, MA': {'weight': 2}, 'New Haven, CT': {'weight': 1}, 'Springfield, MA': {'weight': 1}}
# Akron, OH	 {}
# Brownsville, TX	 {}
# Mobile, AL	 {}
# Newport News, VA	 {'Richmond, VA': {'weight': 1}}
# Tempe, AZ	 {}
# Shreveport, LA	 {}
# Chattanooga, TN	 {}
# Fort Lauderdale, FL	 {'West Palm Beach, FL': {'weight': 1}, 'Hollywood, FL': {'weight': 1}}
# Aurora, IL	 {}
# Elk Grove, CA	 {}
# Ontario, CA	 {'Tucson, AZ': {'weight': 2}, 'Pomona, CA': {'weight': 2}}
# Salem, OR	 {'Eugene, OR': {'weight': 2}, 'Portland, OR': {'weight': 2}}
# Cary, NC	 {'Raleigh, NC': {'weight': 1}, 'Durham, NC': {'weight': 1}, 'Charleston, SC': {'weight': 1}, 'Columbia, SC': {'weight': 1}}
# Santa Rosa, CA	 {}
# Rancho Cucamonga, CA	 {}
# Eugene, OR	 {'Salem, OR': {'weight': 2}, 'Chico, CA': {'weight': 1}}
# Oceanside, CA	 {'Irvine, CA': {'weight': 1}, 'San Diego, CA': {'weight': 1}}
# Clarksville, TN	 {}
# Garden Grove, CA	 {}
# Lancaster, CA	 {}
# Springfield, MO	 {}
# Pembroke Pines, FL	 {}
# Fort Collins, CO	 {}
# Palmdale, CA	 {}
# Salinas, CA	 {'San Jose, CA': {'weight': 1}, 'Oxnard, CA': {'weight': 1}}
# Hayward, CA	 {'Oakland, CA': {'weight': 1}, 'Fremont, CA': {'weight': 1}}
# Corona, CA	 {}
# Paterson, NJ	 {}
# Murfreesboro, TN	 {}
# Macon, GA	 {}
# Lakewood, CO	 {}
# Killeen, TX	 {}
# Springfield, MA	 {'Hartford, CT': {'weight': 4}, 'Syracuse, NY': {'weight': 1}, 'Worcester, MA': {'weight': 1}, 'Providence, RI': {'weight': 1}}
# Alexandria, VA	 {'Washington, DC': {'weight': 5}, 'Cincinnati, OH': {'weight': 1}, 'Richmond, VA': {'weight': 3}, 'Greensboro, NC': {'weight': 1}}
# Kansas City, KS	 {}
# Sunnyvale, CA	 {}
# Hollywood, FL	 {'Fort Lauderdale, FL': {'weight': 1}, 'Miami, FL': {'weight': 1}}
# Roseville, CA	 {'Reno, NV': {'weight': 1}, 'Sacramento, CA': {'weight': 2}}
# Charleston, SC	 {'Fayetteville, NC': {'weight': 1}, 'Cary, NC': {'weight': 1}}
# Escondido, CA	 {}
# Joliet, IL	 {'Chicago, IL': {'weight': 3}, 'Naperville, IL': {'weight': 1}, 'Springfield, IL': {'weight': 2}}
# Jackson, MS	 {'Memphis, TN': {'weight': 1}, 'New Orleans, LA': {'weight': 1}}
# Bellevue, WA	 {}
# Surprise, AZ	 {}
# Naperville, IL	 {'Chicago, IL': {'weight': 2}, 'Omaha, NE': {'weight': 1}, 'Joliet, IL': {'weight': 1}, 'Springfield, IL': {'weight': 1}, 'Kansas City, MO': {'weight': 1}}
# Pasadena, TX	 {}
# Pomona, CA	 {'Ontario, CA': {'weight': 2}, 'Los Angeles, CA': {'weight': 2}}
# Bridgeport, CT	 {'New Haven, CT': {'weight': 2}, 'Stamford, CT': {'weight': 2}}
# Denton, TX	 {}
# Rockford, IL	 {}
# Mesquite, TX	 {}
# Savannah, GA	 {'Columbia, SC': {'weight': 1}, 'Jacksonville, FL': {'weight': 1}}
# Syracuse, NY	 {'Rochester, NY': {'weight': 3}, 'Yonkers, NY': {'weight': 2}, 'Springfield, MA': {'weight': 1}}
# McAllen, TX	 {}
# Torrance, CA	 {}
# Olathe, KS	 {}
# Visalia, CA	 {}
# Thornton, CO	 {}
# Fullerton, CA	 {'Los Angeles, CA': {'weight': 2}, 'Anaheim, CA': {'weight': 1}, 'Riverside, CA': {'weight': 1}}
# Gainesville, FL	 {}
# Waco, TX	 {}
# West Valley City, UT	 {}
# Warren, MI	 {}
# Lakewood, NJ	 {}
# Hampton, VA	 {}
# Dayton, OH	 {}
# Columbia, SC	 {'Cary, NC': {'weight': 1}, 'Savannah, GA': {'weight': 1}}
# Orange, CA	 {}
# Cedar Rapids, IA	 {}
# Stamford, CT	 {'New Haven, CT': {'weight': 1}, 'New York, NY': {'weight': 3}, 'Bridgeport, CT': {'weight': 2}}
# Victorville, CA	 {'Albuquerque, NM': {'weight': 1}, 'San Bernardino, CA': {'weight': 1}}
# Pasadena, CA	 {}
# Elizabeth, NJ	 {}
# New Haven, CT	 {'Providence, RI': {'weight': 1}, 'Stamford, CT': {'weight': 1}, 'Hartford, CT': {'weight': 4}, 'New Haven, CT': {'weight': 6}, 'Bridgeport, CT': {'weight': 2}}
# Miramar, FL	 {}
# Kent, WA	 {}
# Sterling Heights, MI	 {}
# Carrollton, TX	 {}
# Coral Springs, FL	 {}
# Midland, TX	 {}
# Norman, OK	 {'Oklahoma City, OK': {'weight': 1}, 'Fort Worth, TX': {'weight': 1}}
# Athens, GA	 {}
# Santa Clara, CA	 {'Fremont, CA': {'weight': 1}, 'Santa Clara, CA': {'weight': 2}, 'San Jose, CA': {'weight': 1}}
# Columbia, MO	 {}
# Fargo, ND	 {'Minneapolis, MN': {'weight': 1}, 'Spokane, WA': {'weight': 1}}
# Pearland, TX	 {}
# Simi Valley, CA	 {'Oxnard, CA': {'weight': 2}, 'Burbank, CA': {'weight': 2}}
# Meridian, ID	 {}
# Topeka, KS	 {'Kansas City, MO': {'weight': 1}, 'Albuquerque, NM': {'weight': 1}}
# Allentown, PA	 {}
# Thousand Oaks, CA	 {}
# Abilene, TX	 {}
# Vallejo, CA	 {}
# Concord, CA	 {}
# Round Rock, TX	 {}
# Arvada, CO	 {}
# Clovis, CA	 {}
# Palm Bay, FL	 {}
# Independence, MO	 {"Lee's Summit, MO": {'weight': 2}, 'Kansas City, MO': {'weight': 2}}
# Lafayette, LA	 {'New Orleans, LA': {'weight': 1}, 'Beaumont, TX': {'weight': 1}}
# Ann Arbor, MI	 {'Grand Rapids, MI': {'weight': 1}, 'Dearborn, MI': {'weight': 1}}
# Rochester, MN	 {}
# Hartford, CT	 {'Springfield, MA': {'weight': 4}, 'New Haven, CT': {'weight': 4}}
# College Station, TX	 {}
# Fairfield, CA	 {'Vacaville, CA': {'weight': 1}, 'Richmond, CA': {'weight': 1}}
# Wilmington, NC	 {}
# North Charleston, SC	 {}
# Billings, MT	 {}
# West Palm Beach, FL	 {'Lakeland, FL': {'weight': 1}, 'Fort Lauderdale, FL': {'weight': 1}}
# Berkeley, CA	 {'Richmond, CA': {'weight': 1}, 'Oakland, CA': {'weight': 1}}
# Cambridge, MA	 {}
# Clearwater, FL	 {}
# West Jordan, UT	 {}
# Evansville, IN	 {}
# Richardson, TX	 {}
# Broken Arrow, OK	 {}
# Richmond, CA	 {'Fairfield, CA': {'weight': 1}, 'Berkeley, CA': {'weight': 1}, 'Oakland, CA': {'weight': 1}, 'Stockton, CA': {'weight': 1}}
# League City, TX	 {}
# Manchester, NH	 {}
# Lakeland, FL	 {'Tampa, FL': {'weight': 1}, 'Lakeland, FL': {'weight': 2}, 'West Palm Beach, FL': {'weight': 1}}
# Carlsbad, CA	 {}
# Antioch, CA	 {}
# Westminster, CO	 {}
# High Point, NC	 {'Greensboro, NC': {'weight': 2}, 'Charlotte, NC': {'weight': 2}}
# Provo, UT	 {'Denver, CO': {'weight': 1}, 'Salt Lake City, UT': {'weight': 1}}
# Lowell, MA	 {}
# Elgin, IL	 {}
# Waterbury, CT	 {}
# Springfield, IL	 {'Naperville, IL': {'weight': 1}, 'Joliet, IL': {'weight': 2}, 'St. Louis, MO': {'weight': 2}}
# Gresham, OR	 {}
# Murrieta, CA	 {}
# Lewisville, TX	 {}
# Las Cruces, NM	 {}
# Lansing, MI	 {'Chicago, IL': {'weight': 1}, 'Grand Rapids, MI': {'weight': 1}}
# Beaumont, TX	 {'Lafayette, LA': {'weight': 1}, 'Houston, TX': {'weight': 1}}
# Odessa, TX	 {}
# Pueblo, CO	 {}
# Peoria, IL	 {}
# Downey, CA	 {}
# Pompano Beach, FL	 {}
# Miami Gardens, FL	 {}
# Temecula, CA	 {}
# Everett, WA	 {'Seattle, WA': {'weight': 2}, 'Portland, OR': {'weight': 1}}
# Costa Mesa, CA	 {}
# Ventura[, CA	 {}
# Sparks, NV	 {}
# Santa Maria, CA	 {}
# Sugar Land, TX	 {}
# Greeley, CO	 {}
# South Fulton, GA	 {}
# Dearborn, MI	 {'Ann Arbor, MI': {'weight': 1}, 'Detroit, MI': {'weight': 1}}
# Concord, NC	 {}
# Edison, NJ	 {}
# Tyler, TX	 {}
# Sandy Springs, GA	 {}
# West Covina, CA	 {}
# Green Bay, WI	 {}
# Centennial, CO	 {}
# Jurupa Valley, CA	 {}
# El Monte, CA	 {}
# Allen, TX	 {}
# Hillsboro, OR	 {}
# Menifee, CA	 {}
# Nampa, ID	 {}
# Spokane Valley, WA	 {}
# Rio Rancho, NM	 {}
# Brockton, MA	 {}
# El Cajon, CA	 {}
# Burbank, CA	 {'Simi Valley, CA': {'weight': 2}, 'Los Angeles, CA': {'weight': 1}, 'Burbank, CA': {'weight': 2}, 'Glendale, CA': {'weight': 1}}
# Inglewood, CA	 {}
# Renton, WA	 {}
# Davie, FL	 {}
# Rialto, CA	 {}
# Boulder, CO	 {}
# South Bend, IN	 {'Toledo, OH': {'weight': 2}, 'Chicago, IL': {'weight': 2}}
# Woodbridge, NJ	 {}
# Vacaville, CA	 {'Sacramento, CA': {'weight': 1}, 'Fairfield, CA': {'weight': 1}}
# Wichita Falls, TX	 {}
# Lee's Summit, MO	 {'St. Louis, MO': {'weight': 2}, 'Independence, MO': {'weight': 2}}
# Edinburg, TX	 {}
# Chico, CA	 {'Eugene, OR': {'weight': 1}, 'Sacramento, CA': {'weight': 1}}
# San Mateo, CA	 {}
# Bend, OR	 {}
# Goodyear, AZ	 {}
# Buckeye, AZ	 {}
# Daly City, CA	 {}
# Fishers, IN	 {}
# Quincy, MA	 {}
# Davenport, IA	 {}
# Hesperia, CA	 {}
# New Bedford, MA	 {}
# Lynn, MA	 {}
# Carmel, IN	 {}
# Longmont, CO	 {}
# Tuscaloosa, AL	 {'Birmingham, AL': {'weight': 1}}
# Norwalk, CA	 {}

# %% [markdown]
# ## Create GML Files for all created networks

# %%
nx.write_gml(G_amtrak,"Amtrak_Network.gml")
nx.write_gml(G_induced_cities,"Amtrak_Induced_Cities.gml")
nx.write_gml(G_noninduced_cities,"Amtrak_Noninduced_Cities.gml")
